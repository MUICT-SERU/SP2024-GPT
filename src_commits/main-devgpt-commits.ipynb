# %% [markdown]
# # Introduction
# This notebook is part of an empirical studies on changes in markdown files after the release of ChatGPT (30th November 2022). Our hypothesis is that

# %% [markdown]
# # setup

# %%
from dotenv import load_dotenv
import os
import json
import requests
import numpy as np
import pandas as pd
import base64
from tqdm import tqdm
import re
import pandas as pd
import pytz
from datetime import datetime
from tqdm import tqdm
from tabulate import tabulate

# %%
# Load access token
load_dotenv()
gh_token = os.getenv('GH_ACCESS_TOKEN')
print(gh_token)

# GitHub API setup
headers = {'Authorization': f'token {gh_token}'}
# Out:
# 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

# %% [markdown]
# # iterate through snapshots for commits containing .md as modified files

# %%
folders = [
    'snapshot_20231012',
]
files = [
    '20231012_230826_commit_sharings.json',
]

paths = []
for folderpath in folders:
    for filepath in files:
        paths.append('./' + folderpath + '/' + filepath)
print(paths)

data = []
snapshot_counts = {}

# Load the JSON data from each path and add the snapshot name to each commit
for path in paths:
    with open(path) as f:
        d = json.load(f)
        snapshot_name = path.split('/')[-1]  # Extract snapshot name from path
        commits = d['Sources']
        snapshot_counts[snapshot_name] = {'original': len(commits), 'filtered': 0}
        for commit in commits:
            commit['Snapshot'] = snapshot_name
            data.append(commit)

print('Total original size: ', len(data), ' commits')
# Out:
# ['./snapshot_20231012/20231012_230826_commit_sharings.json']
# Total original size:  694  commits

# %%
# Function to fetch modified files from a commit
def get_modified_markdown_files(repo_name, commit_sha):
    url = f'https://api.github.com/repos/{repo_name}/commits/{commit_sha}'
    response = requests.get(url, headers=headers)

    if response.status_code == 200:
        commit_data = response.json()

        # Only retrieve modified .md files
        modified_files = [file['filename'] for file in commit_data['files'] if '.md' in file['filename']]
        # print(f'{repo_name}: {len(modified_files)} modified files')
        return modified_files
    else:
        print(f"Failed to fetch commit {commit_sha} from repo {repo_name}: {response.status_code}")
        return []

# Function to filter commits by date, and check for .md file changes
# Also counts the number of commits per snapshot
def filter_commits(data):
    filtered_commits = []
    for commit in tqdm(data):
        repo_name = commit['RepoName']
        commit_sha = commit['Sha']
        modified_markdowns = get_modified_markdown_files(repo_name, commit_sha)
        if len(modified_markdowns) > 0:
            commit['Modified_markdowns'] = modified_markdowns
            filtered_commits.append(commit)
            snapshot_counts[commit['Snapshot']]['filtered'] += 1
    return filtered_commits

# %%
# Filter the commits based on the cutoff date and .md file modifications
filtered_commits = filter_commits(data)

df = pd.DataFrame(filtered_commits, columns=['Snapshot', 'RepoName', 'Message', 'CommitAt', 'URL', 'Modified_markdowns'])
# Out:
#   0%|          | 1/694 [00:00<06:53,  1.68it/s]
# Failed to fetch commit fa335cf2ec447d00f8e94b54a8b463725b92947c from repo grnpin/textbox: 404
#   0%|          | 2/694 [00:01<05:59,  1.93it/s]
# Failed to fetch commit 0dfc4385b723060e1e6a21da17a952bd908084ff from repo grnpin/textbox: 404
#   0%|          | 3/694 [00:01<06:10,  1.87it/s]
# Failed to fetch commit 811d09acdca361c81281c7d71587ebdbd8437453 from repo grnpin/textbox: 404
# 100%|██████████| 694/694 [06:56<00:00,  1.67it/s]

# %%
# Print the original and filtered commit counts for each snapshot
print("\nOriginal and filtered commit counts per snapshot:")
for snapshot, counts in snapshot_counts.items():
    print(f"{snapshot}: Original={counts['original']}, Filtered={counts['filtered']}")
# Out:
# Original and filtered commit counts per snapshot:
# 20231012_230826_commit_sharings.json: Original=694, Filtered=578

# %%
# Print the filtered commits as a nicely formatted table
print(tabulate(df, headers='keys', tablefmt='psql'))

# Export the filtered commits to a CSV file
df.to_csv('filtered_commits.csv', index=False)
# Out:
# +-----+--------------------------------------+---------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------+----------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |     | Snapshot                             | RepoName                                    | Message                                                                                                                                                                                                                                                                                                               | CommitAt                      | URL                                                                                                            | Modified_markdowns                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |
# |-----+--------------------------------------+---------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------+----------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# |   0 | 20231012_230826_commit_sharings.json | 4lejandrito/fetchbook                       | docs: adding readme                                                                                                                                                                                                                                                                                                   | 2023-10-06T01:01:51.000+02:00 | https://github.com/4lejandrito/fetchbook/commit/11725c1a23503f31f7b7cd13188c8d9e30e822a9                       | ['README.md']                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               |
# |     |                                      |                                             |                                                                                                                                                                                                                                                                                                                       |                               |                                                                                                                |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             |
# |     |                                      |                                             | https://chat.openai.com/share/6b654f3c-3763-4292-92b1-3026e647e505                                                                                                                                                                                                                                                    |                               |                                                                                                                |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             |
# |   1 | 20231012_230826_commit_sharings.json | Hajaradnan/Hajaradnan                       | Create README.md                                                                                                                                                                                                                                                                                                      | 2023-09-24T14:13:30.000+01:00 | https://github.com/Hajaradnan/Hajaradnan/commit/ec6241ca4370129bce7a021a4f80dff123cde103                       | ['README.md']                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               |
# |     |                                      |                                             |                                                                                                                                                                                                                                                                                                                       |                               |                                                                                                                |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             |
# |     |                                      |                                             | https://chat.openai.com/share/49eb1aff-ce9a-4373-ad28-348c2b5addcd                                                                                                                                                                                                                                                    |                               |                                                                                                                |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             |
# |   2 | 20231012_230826_commit_sharings.json | pbrudny/jobsforit-de                        | Update readme                                                                                                                                                                                                                                                                                                         | 2023-09-07T21:59:09.000+02:00 | https://github.com/pbrudny/jobsforit-de/commit/cfb4dc480558f97f890159271237cec86874678f                        | ['README.md']                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               |
# |     |                                      |                                             | * shared chat: https://chat.openai.com/share/73e56b34-fb0d-4056-bfcc-daf800b5d213                                                                                                                                                                                                                                     |                               |                                                                                                                |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             |
# |   3 | 20231012_230826_commit_sharings.json | eshreyareddy/prompting-zomato-reviews       | Update README.md                                                                                                                                                                                                                                                                                                      | 2023-09-04T10:49:30.000+05:30 | https://github.com/eshreyareddy/prompting-zomato-reviews/commit/075750d66c6392147b7cccca28f7c225d9fa6545       | ['README.md']                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               |
# |     |                                      |                                             |                                                                                                                                                                                                                                                                                                                       |                               |                                                                                                                |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             |
# |     |                                      |                                             | https://chat.openai.com/share/52d67aed-45fa-451d-bb95-46d8ba642fa8                                                                                                                                                                                                                                                    |                               |                                                                                                                |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             |
# |   4 | 20231012_230826_commit_sharings.json | jordanbell2357/resume                       | chatgpt                                                                                                                                                                                                                                                                                                               | 2023-08-22T22:14:22.000-04:00 | https://github.com/jordanbell2357/resume/commit/25b8daf69cee3adf71a43a2e235c1143df5ee5ad                       | ['2023-08-22.md', 'ChatGPT.md']                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             |
# |     |                                      |                                             |                                                                                                                                                                                                                                                                                                                       |                               |                                                                                                                |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             |
# |     |                                      |                                             | https://chat.openai.com/share/2b616e34-2067-4682-adbd-9e57fe381f66                                                                                                                                                                                                                                                    |                               |                                                                                                                |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             |
# ...
# |     |                                      |                                             | * I have asked _ChatGPT_ to translate everything. I quickly proof-read some parts and it looks okay, but of course there can be mistakes and I have not used the Skill before, so I don't know what some commands may stand for (e.g. I am confused how I can turn off my computer with Nextcloud via this skill now) |                               |                                                                                                                |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             |
# |     |                                      |                                             | * As for the keyword Sabia I asked ChatGPT, but it was hardly helpful. I ended up just using "Nextcloud" for now, as it is propbably, what it is basically all about.                                                                                                                                                 |                               |                                                                                                                |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             |
# |     |                                      |                                             |                                                                                                                                                                                                                                                                                                                       |                               |                                                                                                                |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             |
# |     |                                      |                                             | source ChatGPT: https://chat.openai.com/share/4c3df48f-27fe-493e-86ac-37124e975a13                                                                                                                                                                                                                                    |                               |                                                                                                                |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             |
# +-----+--------------------------------------+---------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------+----------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+

# %% [markdown]
# # data analysis

# %% [markdown]
# ## projects and commits distributions

# %% [markdown]
# ### remove outlier projects containing too many commits

# %% [markdown]
# Some projects from the DevGPT MSR dataset may have been

# %%
# Load the filtered commits CSV
filtered_df = pd.read_csv('filtered_commits.csv')

# Count the number of commits per project
commit_counts = filtered_df['RepoName'].value_counts()

# Determine the threshold for outliers (e.g., more than 100 commits)
threshold = 100
outliers = commit_counts[commit_counts > threshold].index

# Filter out the outliers
filtered_df_no_outliers = filtered_df[~filtered_df['RepoName'].isin(outliers)]

# Save the cleaned dataframe to a new CSV
filtered_df_no_outliers.to_csv('filtered_commits_no_outliers.csv', index=False)

# Print the filtered dataframe without outliers
print(filtered_df_no_outliers)
# Out:
#                                  Snapshot  \
# 0    20231012_230826_commit_sharings.json
# 1    20231012_230826_commit_sharings.json
# 2    20231012_230826_commit_sharings.json
# 3    20231012_230826_commit_sharings.json
# 4    20231012_230826_commit_sharings.json
# 5    20231012_230826_commit_sharings.json
# 6    20231012_230826_commit_sharings.json
# 7    20231012_230826_commit_sharings.json
# 8    20231012_230826_commit_sharings.json
# 9    20231012_230826_commit_sharings.json
# 27   20231012_230826_commit_sharings.json
# 203  20231012_230826_commit_sharings.json
# 556  20231012_230826_commit_sharings.json
# 570  20231012_230826_commit_sharings.json
# 571  20231012_230826_commit_sharings.json
# 572  20231012_230826_commit_sharings.json
# 573  20231012_230826_commit_sharings.json
# 574  20231012_230826_commit_sharings.json
# 575  20231012_230826_commit_sharings.json
# 576  20231012_230826_commit_sharings.json
# 577  20231012_230826_commit_sharings.json
#
#                                         RepoName  \
# 0                          4lejandrito/fetchbook
# 1                          Hajaradnan/Hajaradnan
# 2                           pbrudny/jobsforit-de
# 3          eshreyareddy/prompting-zomato-reviews
# 4                          jordanbell2357/resume
# 5                                   p3ob7o/Speak
# 6                             tisztamo/vueyourcv
# 7    CPSC-1520/CPSC-1520-Workbook-A02-dgilleland
# 8                                     Hack23/cia
# 9                         mgalgs/github-pr-fetch
# 27                    larrywright/larrywright.me
# 203                              Loknar/loka-ord
# 556        kevinveenbirkenbach/computer-playbook
# 570          harryallerston/RPI-Wireless-Hotspot
# 571            labd/terraform-provider-storyblok
# 572                         TurboWarp/extensions
# 573                     lightward/mechanic-tasks
# 574                      repeatingbeats/dotfiles
# 575                        PrivateBin/PrivateBin
# 576                 gama-platform/gama.benchmark
# 577                 brennoflavio/nextcloud-alexa
#
#                                                Message  \
# 0    docs: adding readme\n\nhttps://chat.openai.com...
# 1    Create README.md\n\nhttps://chat.openai.com/sh...
# 2    Update readme\n* shared chat: https://chat.ope...
# 3    Update README.md\n\nhttps://chat.openai.com/sh...
# 4    chatgpt\n\nhttps://chat.openai.com/share/2b616...
# 5    Refactored entirely based on https://chat.open...
# 6    Update README.md\n\nhttps://chat.openai.com/sh...
# 7    Update lesson 011\n\nDraft content generated t...
# 8    Update dashboard.md\n\nchatlog https://chat.op...
# 9    Initial working version\n\nThanks, ChatGPT!\n\...
# 27   Made some tweaks to the CSS based on input fro...
# 203  chatgpt útbjó eitt orð í grunninn\n\nsjá https...
# 556  Optimized udev rules for backup to usb with th...
# 570  Re-word feature list\n\nI wasn't sure about ho...
# 571  Improve docs to include examples (#9)\n\nExamp...
# 572  Policy on AI (ChatGPT, Bard, etc.) (#1035)\n\n...
# 573   new task based on task request (#282)\n\nhttp...
# 574  Started from scratch after running into issues...
# 575  refactor: redirect support questions to discus...
# 576  fix: various fixes\n\n- Switch to ubuntu 20.04...
# 577  Add German and English translations of intend....
#
#                           CommitAt  \
# 0    2023-10-06T01:01:51.000+02:00
# 1    2023-09-24T14:13:30.000+01:00
# 2    2023-09-07T21:59:09.000+02:00
# 3    2023-09-04T10:49:30.000+05:30
# 4    2023-08-22T22:14:22.000-04:00
# 5    2023-07-06T11:20:49.000-05:00
# 6    2023-06-26T13:49:10.000+02:00
# 7    2023-09-28T05:49:17.000-06:00
# 8    2023-07-09T11:33:06.000+02:00
# 9    2023-07-07T11:55:23.000-07:00
# 27   2023-09-23T14:30:20.000-05:00
# 203       2023-06-10T14:16:16.000Z
# 556  2023-05-27T23:04:22.000+02:00
# 570  2023-06-01T21:42:06.000-06:00
# 571  2023-06-08T16:10:39.000+02:00
# 572  2023-09-22T09:31:09.000-05:00
# 573  2023-09-25T21:46:24.000-05:00
# 574  2023-09-14T16:48:13.000-07:00
# 575       2023-08-07T17:59:07.000Z
# 576  2023-09-05T10:09:25.000+07:00
# 577  2023-09-21T21:02:22.000+02:00
#
#                                                    URL  \
# 0    https://github.com/4lejandrito/fetchbook/commi...
# 1    https://github.com/Hajaradnan/Hajaradnan/commi...
# 2    https://github.com/pbrudny/jobsforit-de/commit...
# 3    https://github.com/eshreyareddy/prompting-zoma...
# 4    https://github.com/jordanbell2357/resume/commi...
# 5    https://github.com/p3ob7o/Speak/commit/01cec3e...
# 6    https://github.com/tisztamo/vueyourcv/commit/6...
# 7    https://github.com/CPSC-1520/CPSC-1520-Workboo...
# 8    https://github.com/Hack23/cia/commit/7b8639cb1...
# 9    https://github.com/mgalgs/github-pr-fetch/comm...
# 27   https://github.com/larrywright/larrywright.me/...
# 203  https://github.com/Loknar/loka-ord/commit/cf96...
# 556  https://github.com/kevinveenbirkenbach/compute...
# 570  https://github.com/harryallerston/RPI-Wireless...
# 571  https://github.com/labd/terraform-provider-sto...
# 572  https://github.com/TurboWarp/extensions/commit...
# 573  https://github.com/lightward/mechanic-tasks/co...
# 574  https://github.com/repeatingbeats/dotfiles/com...
# 575  https://github.com/PrivateBin/PrivateBin/commi...
# 576  https://github.com/gama-platform/gama.benchmar...
# 577  https://github.com/brennoflavio/nextcloud-alex...
#
#                                     Modified_markdowns
# 0                                        ['README.md']
# 1                                        ['README.md']
# 2                                        ['README.md']
# 3                                        ['README.md']
# 4                      ['2023-08-22.md', 'ChatGPT.md']
# 5    ['node_modules/accepts/HISTORY.md', 'node_modu...
# 6                                        ['README.md']
# 7                                ['src/011/ReadMe.md']
# 8                                     ['dashboard.md']
# 9                                        ['README.md']
# 27         ['themes/larrywright.me/archetypes/til.md']
# 203                                      ['README.md']
# 556  ['roles/independent_backup-to-swappable/README...
# 570                                      ['README.md']
# 571  ['docs/index.md', 'docs/resources/component.md...
# 572                                ['CONTRIBUTING.md']
# 573  ['docs/README.md', 'docs/automatically-mark-ne...
# 574                                      ['README.md']
# 575  ['.github/ISSUE_TEMPLATE/bug_report.md', '.git...
# 576                                      ['README.md']
# 577                                      ['README.md']

# %% [markdown]
# ### Retrieve and print the number of original datasets' projects and commits

# %%
# Count the number of unique projects and total commits in the original dataset
original_projects = len(set(commit['RepoName'] for commit in data)) # Exclude header row
original_commits = len(data)

print(f"Number of projects in the original dataset: {original_projects}")
print(f"Number of commits in the original dataset: {original_commits}")
# Out:
# Number of projects in the original dataset: 76
# Number of commits in the original dataset: 694

# %% [markdown]
# ### retrieve and print the number of the filtered csv's projects and commits

# %%
# Count the number of unique projects and total commits in the filtered dataframe
filtered_projects = filtered_df_no_outliers['RepoName'].nunique()
filtered_commits = len(filtered_df_no_outliers) # Exclude header row

print(f"Number of projects in the filtered dataset: {filtered_projects}")
print(f"Number of commits in the filtered dataset: {filtered_commits}")
# Out:
# Number of projects in the filtered dataset: 21
# Number of commits in the filtered dataset: 21

# %% [markdown]
# ### Plot a graph comparing the differences between the original and the filtered csv on the number of projects and commits for each project

# %%
import matplotlib.pyplot as plt

# Calculate the number of commits per project in the original dataset
original_commit_counts = pd.Series([commit['RepoName'] for commit in data]).value_counts()

# Calculate the number of commits per project in the filtered dataset without outliers
filtered_commit_counts = filtered_df_no_outliers['RepoName'].value_counts()

# Plot the number of projects
plt.figure(figsize=(12, 6))
fig, ax = plt.subplots()
original_bar = plt.bar(['Original'], [original_projects], label='Original')
ax.bar_label(original_bar)
filtered_bar = plt.bar(['Markdown-only'], [filtered_projects], label='Markdown-only without outliers')
ax.bar_label(filtered_bar)
plt.xlabel('Dataset')
plt.ylabel('Number of Projects')
plt.title('Number of Projects in Original and Markdown-only Datasets')
plt.legend(loc='upper right')
plt.show()

# Ensure the bins cover the range of commit counts in both datasets
max_commits = max(original_commit_counts.max(), filtered_commit_counts.max())

# Plot the number of commits for each project
fig, ax = plt.subplots()
counts, edges, bars = ax.hist([original_commit_counts, filtered_commit_counts], histtype='bar', label=['Original', 'Markdown-only without outliers'])

# Add bar labels
# reference: https://stackoverflow.com/questions/39841733/matplotlib-histogram-how-to-display-the-count-over-the-bar
for b in bars:
    ax.bar_label(b)

plt.ylabel('Number of Projects')
plt.xlabel('Number of Commits')
plt.title('Number of Commits per Project in Original and Markdown-only Datasets')
plt.legend()
plt.show()

# %% [markdown]
# ## analyzing commit message distributions

# %%
import nltk
from nltk.corpus import stopwords
from collections import Counter
import matplotlib.pyplot as plt

# Load the filtered commits CSV
filtered_df = pd.read_csv('filtered_commits_no_outliers.csv')

# Extract the commit messages
commit_messages = filtered_df['Message']

# Tokenize and preprocess the commit messages
stop_words = set(stopwords.words('english'))
processed_messages = []
for message in commit_messages:
    tokens = nltk.word_tokenize(message.lower())
    filtered_tokens = [token for token in tokens if not re.search(r'[^\w\s]', token) and not re.search(r'\b(chatgpt|https)\b', token) and token not in stop_words]
    processed_messages.extend(filtered_tokens)

# Count the frequency of words
word_freq = Counter(processed_messages)

# Get the top 20 most frequent words
top_words = word_freq.most_common(20)

# Plot the word frequency graph
words, counts = zip(*top_words)
fig, ax = plt.subplots()
bar = plt.bar(words, counts)
ax.bar_label(bar)
plt.xlabel('Word')
plt.ylabel('Frequency')
plt.title('Word Frequency in Commit Messages')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## analyze types of modified markdown files

# %%
# Extract the modified Markdown file names
modified_files = [file for sublist in filtered_df['Modified_markdowns'] for file in sublist]

# Categorize the file names
file_categories = {}
for file_name in modified_files:
    category = file_name.split('.')[0].lower()
    file_categories[category] = file_categories.get(category, 0) + 1

# Print the distribution of file categories
print("Distribution of modified Markdown file types:")
for category, count in sorted(file_categories.items(), key=lambda x: x[1], reverse=True):
    print(f"{category}: {count}")
# Out:
# Distribution of modified Markdown file types:
# e: 337
# d: 310
# m: 213
# o: 212
# ': 170
# /: 151
# s: 147
# r: 130
# a: 119
# n: 117
# l: 96
# u: 91
# : 89
# t: 83
# i: 74
# _: 68
# ,: 64
#  : 64
# c: 49
# -: 39
# p: 36
# y: 33
# h: 32
# b: 27
# g: 23
# [: 21
# ]: 21
# f: 20
# x: 12
# k: 11
# w: 6
# 2: 4
# v: 4
# 0: 3
# 1: 2
# 3: 1
# 8: 1
# q: 1

# %% [markdown]
# ## investigating the relationship between project characteristics and documentation changes

# %%
# Load the original dataset with project characteristics
original_data = pd.read_json(data)

# Merge the original data with the filtered commits
merged_data = pd.merge(filtered_df, original_data[['RepoName', 'RepoLanguage']], on='RepoName', how='left')

# Analyze the relationship between programming language and number of documentation changes
language_counts = merged_data.groupby('RepoLanguage')['Modified_markdowns'].apply(lambda x: sum(len(files) for files in x))
language_counts.sort_values(ascending=False, inplace=True)
print("Number of documentation changes by programming language:")
print(language_counts)

# %% [markdown]
# # comparing the differences between current filtered files and on commits before ChatGPT releases
