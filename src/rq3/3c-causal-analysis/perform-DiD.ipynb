# %% [markdown]
# # DiD New Metrics

# %%
import pandas as pd
import statsmodels.formula.api as smf
import os

# Directory containing the aligned files
# aligned_dir = "aligned_did_outputs"
# metrics = ['stars', 'forks', 'commits', 'prs', 've_contributors']
# metric_column_map = {
#     "stars": "cumulative_stars",
#     "forks": "cumulative_forks",
#     "commits": "cumulative_commits",
#     "prs": "cumulative_prs",
#     "ve_contributors": "cumulative_ve_contributors"
# }

aligned_dir = "aligned_did_outputs_new"
metrics = ['new_stars', 'new_forks', 'new_commits', 'new_prs', 'active_contributors']
metric_column_map = {
    "new_stars": "new_stars",
    "new_forks": "new_forks",
    "new_commits": "new_commits",
    "new_prs": "new_prs",
    "active_contributors": "active_contributors"
}

results = {}

for metric in metrics:
    file_path = os.path.join(aligned_dir, f"aligned_did_{metric}.csv")
    df = pd.read_csv(file_path)

    if df.empty:
        print(f"[!] Skipping empty file: {file_path}")
        continue

    # Prep binary indicators
    df['treatment'] = (df['repo_type'] == 'treatment').astype(int)
    df['post'] = df['post_treatment'].astype(int)

    # DiD interaction term is treatment * post
    df['did'] = df['treatment'] * df['post']

    # Choose outcome metric
    outcome = metric_column_map[metric]

    # Run DiD regression
    model = smf.ols(formula=f"{outcome} ~ treatment + post + did", data=df).fit(cov_type='HC3')

    print(f"\n===== DiD Result: {outcome} =====")
    print(model.summary())
    results[metric] = model
# Out:
# ===== DiD Result: new_stars =====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              new_stars   R-squared:                       0.022
# Model:                            OLS   Adj. R-squared:                  0.020
# Method:                 Least Squares   F-statistic:                     9.800
# Date:                Fri, 11 Apr 2025   Prob (F-statistic):           2.08e-06
# Time:                        02:32:38   Log-Likelihood:                -10131.
# No. Observations:                1640   AIC:                         2.027e+04
# Df Residuals:                    1636   BIC:                         2.029e+04
# Df Model:                           3
# Covariance Type:                  HC3
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      3.8387      0.285     13.446      0.000       3.279       4.398
# treatment      1.5780      0.477      3.309      0.001       0.643       2.513
# post          -0.2249      0.410     -0.548      0.584      -1.029       0.579
# did           38.3462     10.565      3.629      0.000      17.639      59.054
# ==============================================================================
# Omnibus:                     4262.882   Durbin-Watson:                   1.818
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         64332018.149
# Skew:                          28.640   Prob(JB):                         0.00
# Kurtosis:                     971.588   Cond. No.                         7.18
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
#
# ===== DiD Result: new_forks =====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              new_forks   R-squared:                       0.022
# Model:                            OLS   Adj. R-squared:                  0.021
# Method:                 Least Squares   F-statistic:                     13.46
# Date:                Fri, 11 Apr 2025   Prob (F-statistic):           1.04e-08
# Time:                        02:32:38   Log-Likelihood:                -10990.
# No. Observations:                2394   AIC:                         2.199e+04
# Df Residuals:                    2390   BIC:                         2.201e+04
# Df Model:                           3
# Covariance Type:                  HC3
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      3.6660      0.258     14.218      0.000       3.161       4.171
# treatment      0.9536      0.392      2.430      0.015       0.185       1.723
# post          -0.6706      0.343     -1.955      0.051      -1.343       0.002
# did            7.6908      1.790      4.296      0.000       4.182      11.199
# ==============================================================================
# Omnibus:                     5111.955   Durbin-Watson:                   1.198
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         18813336.095
# Skew:                          18.384   Prob(JB):                         0.00
# Kurtosis:                     435.727   Cond. No.                         7.20
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
#
# ===== DiD Result: new_commits =====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            new_commits   R-squared:                       0.013
# Model:                            OLS   Adj. R-squared:                  0.010
# Method:                 Least Squares   F-statistic:                     5.989
# Date:                Fri, 11 Apr 2025   Prob (F-statistic):           0.000479
# Time:                        02:32:38   Log-Likelihood:                -4713.4
# No. Observations:                1042   AIC:                             9435.
# Df Residuals:                    1038   BIC:                             9455.
# Df Model:                           3
# Covariance Type:                  HC3
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      2.7778      0.386      7.198      0.000       2.021       3.534
# treatment      0.7949      0.586      1.357      0.175      -0.354       1.943
# post           2.1769      1.985      1.097      0.273      -1.714       6.068
# did            3.4595      2.539      1.362      0.173      -1.518       8.437
# ==============================================================================
# Omnibus:                     1907.620   Durbin-Watson:                   1.058
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1766700.509
# Skew:                          12.782   Prob(JB):                         0.00
# Kurtosis:                     203.095   Cond. No.                         7.21
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
#
# ===== DiD Result: new_prs =====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                new_prs   R-squared:                       0.014
# Model:                            OLS   Adj. R-squared:                  0.012
# Method:                 Least Squares   F-statistic:                     11.70
# Date:                Fri, 11 Apr 2025   Prob (F-statistic):           1.51e-07
# Time:                        02:32:38   Log-Likelihood:                -3691.3
# No. Observations:                1058   AIC:                             7391.
# Df Residuals:                    1054   BIC:                             7411.
# Df Model:                           3
# Covariance Type:                  HC3
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.1157      0.196      5.683      0.000       0.731       1.501
# treatment      1.7686      0.371      4.769      0.000       1.042       2.495
# post           0.7623      0.671      1.135      0.256      -0.554       2.078
# did           -0.0160      0.923     -0.017      0.986      -1.825       1.793
# ==============================================================================
# Omnibus:                     1581.912   Durbin-Watson:                   0.543
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           479173.042
# Skew:                           8.752   Prob(JB):                         0.00
# Kurtosis:                     105.778   Cond. No.                         7.15
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
#
# ===== DiD Result: active_contributors =====
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     active_contributors   R-squared:                       0.019
# Model:                             OLS   Adj. R-squared:                  0.018
# Method:                  Least Squares   F-statistic:                     16.69
# Date:                 Fri, 11 Apr 2025   Prob (F-statistic):           9.46e-11
# Time:                         02:32:38   Log-Likelihood:                -9724.5
# No. Observations:                 2990   AIC:                         1.946e+04
# Df Residuals:                     2986   BIC:                         1.948e+04
# Df Model:                            3
# Covariance Type:                   HC3
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      3.0015      0.209     14.345      0.000       2.591       3.412
# treatment      0.9780      0.285      3.432      0.001       0.419       1.537
# post           0.0096      0.311      0.031      0.975      -0.601       0.620
# did            1.0811      0.449      2.407      0.016       0.201       1.961
# ==============================================================================
# Omnibus:                     1775.696   Durbin-Watson:                   0.337
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            13715.302
# Skew:                           2.826   Prob(JB):                         0.00
# Kurtosis:                      11.839   Cond. No.                         7.15
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)

# %% [markdown]
# # DiD cumulative metrics

# %%
import pandas as pd
import statsmodels.formula.api as smf
import os

# Directory containing the aligned files
aligned_dir = "aligned_did_outputs"
metrics = ['stars', 'forks', 'commits', 'prs', 've_contributors']
metric_column_map = {
    "stars": "cumulative_stars",
    "forks": "cumulative_forks",
    "commits": "cumulative_commits",
    "prs": "cumulative_prs",
    "ve_contributors": "cumulative_ve_contributors"
}

results = {}

for metric in metrics:
    file_path = os.path.join(aligned_dir, f"aligned_did_{metric}.csv")
    df = pd.read_csv(file_path)

    if df.empty:
        print(f"[!] Skipping empty file: {file_path}")
        continue

    # Prep binary indicators
    df['treatment'] = (df['repo_type'] == 'treatment').astype(int)
    df['post'] = df['post_treatment'].astype(int)

    # DiD interaction term is treatment * post
    df['did'] = df['treatment'] * df['post']

    # Choose outcome metric
    outcome = metric_column_map[metric]

    # Run DiD regression
    model = smf.ols(formula=f"{outcome} ~ treatment + post + did", data=df).fit(cov_type='HC3')

    print(f"\n===== DiD Result: {outcome} =====")
    print(model.summary())
    results[metric] = model
# Out:
# ===== DiD Result: cumulative_stars =====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       cumulative_stars   R-squared:                       0.068
# Model:                            OLS   Adj. R-squared:                  0.066
# Method:                 Least Squares   F-statistic:                     22.32
# Date:                Fri, 11 Apr 2025   Prob (F-statistic):           3.45e-14
# Time:                        02:51:33   Log-Likelihood:                -13940.
# No. Observations:                1816   AIC:                         2.789e+04
# Df Residuals:                    1812   BIC:                         2.791e+04
# Df Model:                           3
# Covariance Type:                  HC3
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     57.7007      4.044     14.267      0.000      49.774      65.627
# treatment      0.7348      5.626      0.131      0.896     -10.292      11.761
# post          22.6313      6.284      3.602      0.000      10.316      34.947
# did          299.6716     44.946      6.667      0.000     211.579     387.765
# ==============================================================================
# Omnibus:                     3203.608   Durbin-Watson:                   0.374
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          2932480.782
# Skew:                          12.231   Prob(JB):                         0.00
# Kurtosis:                     198.338   Cond. No.                         7.18
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
#
# ===== DiD Result: cumulative_forks =====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       cumulative_forks   R-squared:                       0.056
# Model:                            OLS   Adj. R-squared:                  0.054
# Method:                 Least Squares   F-statistic:                     24.48
# Date:                Fri, 11 Apr 2025   Prob (F-statistic):           1.31e-15
# Time:                        02:51:33   Log-Likelihood:                -15537.
# No. Observations:                2524   AIC:                         3.108e+04
# Df Residuals:                    2520   BIC:                         3.111e+04
# Df Model:                           3
# Covariance Type:                  HC3
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     22.1634      2.094     10.582      0.000      18.059      26.268
# treatment      2.2777      2.998      0.760      0.447      -3.599       8.154
# post           7.9607      3.269      2.435      0.015       1.554      14.368
# did           55.1177      8.457      6.518      0.000      38.543      71.693
# ==============================================================================
# Omnibus:                     3918.564   Durbin-Watson:                   0.354
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          2074564.957
# Skew:                           9.641   Prob(JB):                         0.00
# Kurtosis:                     142.121   Cond. No.                         7.20
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
#
# ===== DiD Result: cumulative_commits =====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     cumulative_commits   R-squared:                       0.062
# Model:                            OLS   Adj. R-squared:                  0.061
# Method:                 Least Squares   F-statistic:                     31.91
# Date:                Fri, 11 Apr 2025   Prob (F-statistic):           4.05e-20
# Time:                        02:51:33   Log-Likelihood:                -11075.
# No. Observations:                1898   AIC:                         2.216e+04
# Df Residuals:                    1894   BIC:                         2.218e+04
# Df Model:                           3
# Covariance Type:                  HC3
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     43.1137      2.466     17.485      0.000      38.281      47.947
# treatment     -1.5754      3.468     -0.454      0.650      -8.372       5.221
# post          17.0176      4.181      4.070      0.000       8.823      25.212
# did           35.4383      7.235      4.898      0.000      21.258      49.618
# ==============================================================================
# Omnibus:                     1600.869   Durbin-Watson:                   0.273
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            57232.006
# Skew:                           3.786   Prob(JB):                         0.00
# Kurtosis:                      28.814   Cond. No.                         7.17
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
#
# ===== DiD Result: cumulative_prs =====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         cumulative_prs   R-squared:                       0.020
# Model:                            OLS   Adj. R-squared:                  0.019
# Method:                 Least Squares   F-statistic:                     9.303
# Date:                Fri, 11 Apr 2025   Prob (F-statistic):           4.16e-06
# Time:                        02:51:33   Log-Likelihood:                -12104.
# No. Observations:                1968   AIC:                         2.422e+04
# Df Residuals:                    1964   BIC:                         2.424e+04
# Df Model:                           3
# Covariance Type:                  HC3
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     37.1969      4.377      8.499      0.000      28.619      45.775
# treatment      2.5973      6.214      0.418      0.676      -9.582      14.777
# post           6.5061      6.119      1.063      0.288      -5.487      18.499
# did           30.5624     10.029      3.048      0.002      10.907      50.218
# ==============================================================================
# Omnibus:                     2400.286   Durbin-Watson:                   0.103
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           237744.348
# Skew:                           6.564   Prob(JB):                         0.00
# Kurtosis:                      55.220   Cond. No.                         7.13
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
#
# ===== DiD Result: cumulative_ve_contributors =====
#                                 OLS Regression Results
# ======================================================================================
# Dep. Variable:     cumulative_ve_contributors   R-squared:                       0.078
# Model:                                    OLS   Adj. R-squared:                  0.077
# Method:                         Least Squares   F-statistic:                     65.08
# Date:                        Fri, 11 Apr 2025   Prob (F-statistic):           8.05e-41
# Time:                                02:51:33   Log-Likelihood:                -15040.
# No. Observations:                        3146   AIC:                         3.009e+04
# Df Residuals:                            3142   BIC:                         3.011e+04
# Df Model:                                   3
# Covariance Type:                          HC3
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     14.3477      0.779     18.418      0.000      12.821      15.875
# treatment      1.6745      1.053      1.590      0.112      -0.390       3.739
# post           6.3888      1.235      5.173      0.000       3.968       8.809
# did           12.8934      1.980      6.512      0.000       9.013      16.774
# ==============================================================================
# Omnibus:                     1655.276   Durbin-Watson:                   0.170
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            11345.768
# Skew:                           2.459   Prob(JB):                         0.00
# Kurtosis:                      10.897   Cond. No.                         7.15
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)

# %% [markdown]
# # further analysis test

# %% [markdown]
# lagstars

# %%
# for lagged value you need to sort first
df = df.sort_values(by=['repo_full_name', 'month'])
df['lag_stars'] = df.groupby('repo_full_name')['cumulative_stars'].shift(1)

model = smf.ols("cumulative_stars ~ lag_stars + treatment + post_treatment + did", data=df)\
           .fit(cov_type='HC3')
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       cumulative_stars   R-squared:                       0.980
# Model:                            OLS   Adj. R-squared:                  0.980
# Method:                 Least Squares   F-statistic:                     3747.
# Date:                Fri, 11 Apr 2025   Prob (F-statistic):               0.00
# Time:                        02:57:02   Log-Likelihood:                -22055.
# No. Observations:                2993   AIC:                         4.412e+04
# Df Residuals:                    2988   BIC:                         4.415e+04
# Df Model:                           4
# Covariance Type:                  HC3
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept         -2.1028      0.533     -3.945      0.000      -3.148      -1.058
# lag_stars          1.0979      0.013     82.109      0.000       1.072       1.124
# treatment         26.8166     13.447      1.994      0.046       0.461      53.172
# post_treatment    -1.8704      0.429     -4.362      0.000      -2.711      -1.030
# did               39.5116     21.549      1.834      0.067      -2.725      81.748
# ==============================================================================
# Omnibus:                     5043.709   Durbin-Watson:                   1.151
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          4524547.051
# Skew:                          11.285   Prob(JB):                         0.00
# Kurtosis:                     192.134   Cond. No.                     1.36e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# [2] The condition number is large, 1.36e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
from pandas.tseries.offsets import DateOffset

# Convert to datetime just in case
df['hn_submission_date'] = pd.to_datetime(df['hn_submission_date'])
df['month'] = pd.to_datetime(df['month'])

# Subtract 3 months row-by-row to make placebo HN date
df['placebo_date'] = df['hn_submission_date'].apply(lambda d: d - DateOffset(months=3))

# Define placebo post-treatment and interaction term
df['post_placebo'] = (df['month'] >= df['placebo_date']).astype(int)
df['placebo_did'] = df['treatment'] * df['post_placebo']

# Run placebo DiD regression
model = smf.ols("cumulative_stars ~ treatment + post_placebo + placebo_did", data=df.dropna())\
           .fit(cov_type='HC3')
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       cumulative_stars   R-squared:                       0.018
# Model:                            OLS   Adj. R-squared:                  0.017
# Method:                 Least Squares   F-statistic:                 1.326e+16
# Date:                Fri, 11 Apr 2025   Prob (F-statistic):               0.00
# Time:                        03:05:22   Log-Likelihood:                -13966.
# No. Observations:                1451   AIC:                         2.794e+04
# Df Residuals:                    1448   BIC:                         2.795e+04
# Df Model:                           2
# Covariance Type:                  HC3
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept    -5.715e+14   4.96e+06  -1.15e+08      0.000   -5.72e+14   -5.72e+14
# treatment     5.715e+14   4.96e+06   1.15e+08      0.000    5.72e+14    5.72e+14
# post_placebo  1.733e+15    1.5e+07   1.15e+08      0.000    1.73e+15    1.73e+15
# placebo_did  -1.733e+15    1.5e+07  -1.15e+08      0.000   -1.73e+15   -1.73e+15
# ==============================================================================
# Omnibus:                     1435.722   Durbin-Watson:                   0.278
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            65976.389
# Skew:                           4.754   Prob(JB):                         0.00
# Kurtosis:                      34.636   Cond. No.                     9.25e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# [2] The smallest eigenvalue is 5.57e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# c:\Users\prach\miniconda3\envs\naist-2025\Lib\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 3, but rank is 1
#   warnings.warn('covariance of constraints does not have full '

# %%
import pandas as pd
import statsmodels.formula.api as smf
import os
from pandas.tseries.offsets import DateOffset

# ===== Configuration =====
aligned_dirs = {
    "cumulative": {
        "dir": "aligned_did_outputs",
        "metrics": ['stars', 'forks', 'commits', 'prs', 've_contributors'],
        "prefix": "cumulative_"
    },
    "non_cumulative": {
        "dir": "aligned_did_outputs_new",
        "metrics": ['new_stars', 'new_forks', 'new_commits', 'new_prs', 'active_contributors'],
        "prefix": ""
    }
}

# ===== Main Analysis =====
for data_type, config in aligned_dirs.items():
    print(f"\n{'='*50}\nAnalyzing {data_type} metrics\n{'='*50}")

    for metric in config['metrics']:
        # Load data
        file_path = os.path.join(config['dir'], f"aligned_did_{metric}.csv")
        try:
            df = pd.read_csv(file_path)
            if df.empty:
                print(f"[!] Skipping empty file: {file_path}")
                continue
        except FileNotFoundError:
            print(f"[!] File not found: {file_path}")
            continue

        # Prep variables
        outcome = f"{config['prefix']}{metric}" if config['prefix'] else metric
        df['treatment'] = (df['repo_type'] == 'treatment').astype(int)
        df['post'] = df['post_treatment'].astype(int)
        df['did'] = df['treatment'] * df['post']

        # ===== 1. Original DiD =====
        model_did = smf.ols(f"{outcome} ~ treatment + post + did", data=df).fit(cov_type='HC3')
        print(f"\n[Original DiD] {outcome}:")
        print(f"DID coefficient: {model_did.params['did']:.4f} (p={model_did.pvalues['did']:.4f})")

        # ===== 2. Lagged Metric Analysis =====
        df = df.sort_values(by=['repo_full_name', 'month'])
        df['lagged_outcome'] = df.groupby('repo_full_name')[outcome].shift(1)

        if df['lagged_outcome'].notnull().any():  # Only run if lag exists
            model_lag = smf.ols(
                f"{outcome} ~ lagged_outcome + treatment + post + did",
                data=df.dropna(subset=['lagged_outcome'])
            ).fit(cov_type='HC3')
            print(f"\n[Lagged Model] {outcome}:")
            print(f"DID coefficient with lag: {model_lag.params['did']:.4f} (p={model_lag.pvalues['did']:.4f})")

        # ===== 3. Placebo Test =====
        # df['hn_submission_date'] = pd.to_datetime(df['hn_submission_date'])
        # df['month'] = pd.to_datetime(df['month'])
        # df['placebo_date'] = df['hn_submission_date'].apply(lambda d: d - DateOffset(months=3))
        # df['post_placebo'] = (df['month'] >= df['placebo_date']).astype(int)
        df['post_placebo'] = (df['relative_month'] >= -3).astype(int)
        df['placebo_did'] = df['treatment'] * df['post_placebo']

        model_placebo = smf.ols(
            f"{outcome} ~ treatment + post_placebo + placebo_did",
            data=df.dropna()
        ).fit(cov_type='HC3')
        print(f"\n[Placebo Test] {outcome}:")
        print(f"Placebo DID coefficient: {model_placebo.params['placebo_did']:.4f} (p={model_placebo.pvalues['placebo_did']:.4f})")
        print("-"*80)
# Out:
# ==================================================
# Analyzing cumulative metrics
# ==================================================
#
# [Original DiD] cumulative_stars:
# DID coefficient: 299.6716 (p=0.0000)
#
# [Lagged Model] cumulative_stars:
# DID coefficient with lag: 30.1163 (p=0.0141)
#
# [Placebo Test] cumulative_stars:
# Placebo DID coefficient: -47566844174619.1641 (p=0.0000)
# --------------------------------------------------------------------------------
#
# [Original DiD] cumulative_forks:
# DID coefficient: 55.1177 (p=0.0000)
#
# [Lagged Model] cumulative_forks:
# DID coefficient with lag: 2.8698 (p=0.0415)
#
# [Placebo Test] cumulative_forks:
# Placebo DID coefficient: 24.3053 (p=0.0000)
# --------------------------------------------------------------------------------
#
# [Original DiD] cumulative_commits:
# DID coefficient: 35.4383 (p=0.0000)
#
# [Lagged Model] cumulative_commits:
# DID coefficient with lag: 0.7125 (p=0.6645)
#
# [Placebo Test] cumulative_commits:
# Placebo DID coefficient: 21.6388 (p=0.0000)
# --------------------------------------------------------------------------------
#
# [Original DiD] cumulative_prs:
# DID coefficient: 30.5624 (p=0.0023)
#
# [Lagged Model] cumulative_prs:
# DID coefficient with lag: 2.6483 (p=0.0002)
#
# [Placebo Test] cumulative_prs:
# Placebo DID coefficient: 46992201775829.0703 (p=0.0000)
# --------------------------------------------------------------------------------
#
# [Original DiD] cumulative_ve_contributors:
# DID coefficient: 12.8934 (p=0.0000)
#
# [Lagged Model] cumulative_ve_contributors:
# DID coefficient with lag: 0.3139 (p=0.0889)
#
# [Placebo Test] cumulative_ve_contributors:
# Placebo DID coefficient: -34635944320410.3008 (p=0.0000)
# --------------------------------------------------------------------------------
#
# ==================================================
# Analyzing non_cumulative metrics
# ==================================================
#
# [Original DiD] new_stars:
# DID coefficient: 38.3462 (p=0.0003)
#
# [Lagged Model] new_stars:
# DID coefficient with lag: 35.7064 (p=0.0018)
#
# [Placebo Test] new_stars:
# Placebo DID coefficient: 13.5524 (p=0.0003)
# --------------------------------------------------------------------------------
#
# [Original DiD] new_forks:
# DID coefficient: 7.6908 (p=0.0000)
#
# [Lagged Model] new_forks:
# DID coefficient with lag: 4.7324 (p=0.0009)
#
# [Placebo Test] new_forks:
# Placebo DID coefficient: -6939452095824.5244 (p=0.3165)
# --------------------------------------------------------------------------------
#
# [Original DiD] new_commits:
# DID coefficient: 3.4595 (p=0.1731)
#
# [Lagged Model] new_commits:
# DID coefficient with lag: 1.8800 (p=0.5476)
#
# [Placebo Test] new_commits:
# Placebo DID coefficient: -50037588738413.5234 (p=0.0000)
# --------------------------------------------------------------------------------
#
# [Original DiD] new_prs:
# DID coefficient: -0.0160 (p=0.9862)
#
# [Lagged Model] new_prs:
# DID coefficient with lag: -0.5757 (p=0.4057)
#
# [Placebo Test] new_prs:
# Placebo DID coefficient: 0.3537 (p=0.3134)
# --------------------------------------------------------------------------------
#
# [Original DiD] active_contributors:
# DID coefficient: 1.0811 (p=0.0161)
#
# [Lagged Model] active_contributors:
# DID coefficient with lag: -0.0315 (p=0.8571)
#
# [Placebo Test] active_contributors:
# Placebo DID coefficient: 3752351530784.9097 (p=0.0000)
# --------------------------------------------------------------------------------

# %% [markdown]
# # not sure

# %%
# import pandas as pd
# import statsmodels.formula.api as smf
# import os

# # Settings
# aligned_dir = "aligned_did_outputs"
# metrics = ['stars', 'forks', 'commits', 'prs', 've_contributors']
# metric_column_map = {
#     "stars": "cumulative_stars",
#     "forks": "cumulative_forks",
#     "commits": "cumulative_commits",
#     "prs": "cumulative_prs",
#     "ve_contributors": "cumulative_ve_contributors"
# }

# results = {}

# for metric in metrics:
#     file_path = os.path.join(aligned_dir, f"aligned_did_{metric}.csv")
#     df = pd.read_csv(file_path)

#     if df.empty:
#         print(f"[!] Skipping empty file: {file_path}")
#         continue

#     # Prep indicators
#     df['treatment'] = (df['repo_type'] == 'treatment').astype(int)
#     df['post'] = df['post_treatment'].astype(int)
#     df['did'] = df['treatment'] * df['post']

#     # Convert to categorical for fixed effects
#     df['repo_full_name'] = df['repo_full_name'].astype('category')
#     df['month'] = pd.to_datetime(df['month']).dt.to_period("M").astype(str)

#     # Regression with repo and month fixed effects
#     outcome = metric_column_map[metric]
#     formula = f"{outcome} ~ did + C(repo_full_name) + C(month)"

#     model = smf.ols(formula=formula, data=df).fit(cov_type='HC3')

#     print(f"\n===== DiD with Fixed Effects: {outcome} =====")
#     print(model.summary())
#     results[metric] = model
# Out:
# ===== DiD with Fixed Effects: cumulative_stars =====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       cumulative_stars   R-squared:                       0.482
# Model:                            OLS   Adj. R-squared:                  0.435
# Method:                 Least Squares   F-statistic:                     36.39
# Date:                Tue, 08 Apr 2025   Prob (F-statistic):               0.00
# Time:                        11:21:17   Log-Likelihood:                -13406.
# No. Observations:                1816   AIC:                         2.712e+04
# Df Residuals:                    1663   BIC:                         2.796e+04
# Df Model:                         152
# Covariance Type:                  HC3
# =====================================================================================================================================================
#                                                                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                                           -77.5107     48.597     -1.595      0.111    -172.760      17.738
# C(repo_full_name)[T.9600dev/llmvm]                                                 -210.0222     63.331     -3.316      0.001    -334.149     -85.895
# C(repo_full_name)[T.AIIX/Mycroft-AI-Gnome-Shell-Extension]                          -36.3455     22.474     -1.617      0.106     -80.394       7.703
# C(repo_full_name)[T.AdrienGuille/GrowingNeuralGas]                                   76.4368     27.713      2.758      0.006      22.120     130.753
# C(repo_full_name)[T.Aggregate-Intellect/sherpa]                                    -205.7914     62.851     -3.274      0.001    -328.978     -82.605
# C(repo_full_name)[T.AlfTang/Neural-Nework]                                          -91.1649     33.903     -2.689      0.007    -157.614     -24.716
# C(repo_full_name)[T.BaihaiAI/IDP]                                                   -69.1962     56.251     -1.230      0.219    -179.446      41.053
# C(repo_full_name)[T.BenderV/ada]                                                   -202.0222     63.068     -3.203      0.001    -325.633     -78.411
# C(repo_full_name)[T.BobMcDear/attorch]                                               -3.6227     35.751     -0.101      0.919     -73.694      66.449
# C(repo_full_name)[T.BobbyAnguelov/NeuralNetwork]                                    -63.7800     32.363     -1.971      0.049    -127.210      -0.350
# C(repo_full_name)[T.CeytiX/AI-Chatbot]                                              -83.3336     33.868     -2.461      0.014    -149.714     -16.953
# C(repo_full_name)[T.CodePilotai/codepilot]                                          -65.3808     48.576     -1.346      0.178    -160.587      29.826
# C(repo_full_name)[T.CognitiveBuild/Chatbot]                                         -21.3534     24.063     -0.887      0.375     -68.516      25.809
# C(repo_full_name)[T.Eroxl/Note-Rack]                                               -164.0342     45.122     -3.635      0.000    -252.472     -75.596
# C(repo_full_name)[T.GoogleCloudPlatform/document-ai-samples]                         68.2243     23.588      2.892      0.004      21.992     114.456
# C(repo_full_name)[T.GoogleCloudPlatform/healthcare-nlp-visualizer-demo]             -38.6350     24.654     -1.567      0.117     -86.956       9.686
# C(repo_full_name)[T.IndoNLP/indonlu]                                                -49.6381     47.645     -1.042      0.297    -143.021      43.744
# C(repo_full_name)[T.JStumpp/awesome-chatbots]                                       -20.7237     30.388     -0.682      0.495     -80.283      38.836
# C(repo_full_name)[T.LucasBassetti/react-simple-chatbot]                             146.7501     22.889      6.411      0.000     101.889     191.611
# C(repo_full_name)[T.MichelDeudon/neural-combinatorial-optimization-rl-tensorflow]   -16.1148     22.412     -0.719      0.472     -60.042      27.812
# C(repo_full_name)[T.NeuralCoder3/transpilation]                                    -214.0991     64.410     -3.324      0.001    -340.340     -87.858
# C(repo_full_name)[T.Oxen-AI/oxen-release]                                           176.0037     43.960      4.004      0.000      89.843     262.165
# C(repo_full_name)[T.PABannier/bark.cpp]                                             225.3004     37.169      6.062      0.000     152.451     298.149
# C(repo_full_name)[T.Puchaczov/Musoq]                                               -194.6224     59.681     -3.261      0.001    -311.595     -77.650
# C(repo_full_name)[T.RTBHOUSE/neural-network-native-ops]                             -17.4110     23.334     -0.746      0.456     -63.145      28.323
# C(repo_full_name)[T.ReadableLabs/readable-vscode]                                  -136.4579     61.449     -2.221      0.026    -256.895     -16.020
# C(repo_full_name)[T.Sergio0694/NeuralNetwork.NET]                                    32.1109     22.968      1.398      0.162     -12.906      77.128
# C(repo_full_name)[T.Sets88/sets88_telegram_bot]                                    -180.4051     50.231     -3.592      0.000    -278.856     -81.954
# C(repo_full_name)[T.StackOverflowMATLABchat/NeuralNetPlayground]                    -49.0768     26.266     -1.868      0.062    -100.557       2.403
# C(repo_full_name)[T.SysCoder/tic-tac-toe-ai-engine]                                 -75.1646     32.673     -2.300      0.021    -139.203     -11.126
# C(repo_full_name)[T.Tauffer-Consulting/domino]                                     -152.3808     44.333     -3.437      0.001    -239.271     -65.490
# C(repo_full_name)[T.ZackAkil/rgb-neural-net]                                        -78.1797     33.650     -2.323      0.020    -144.132     -12.228
# C(repo_full_name)[T.abhiskk/fast-neural-style]                                      -23.6946     23.224     -1.020      0.308     -69.212      21.823
# C(repo_full_name)[T.agermanidis/SnapchatBot]                                         36.8774     25.034      1.473      0.141     -12.188      85.942
# C(repo_full_name)[T.ahmetaa/turkish-nlp-examples]                                   -10.5660     27.718     -0.381      0.703     -64.893      43.761
# C(repo_full_name)[T.alexjc/neural-enhance]                                          235.2538     31.142      7.554      0.000     174.216     296.291
# C(repo_full_name)[T.alfredfrancis/ai-chatbot-framework]                             246.9891     28.618      8.630      0.000     190.898     303.080
# C(repo_full_name)[T.anishathalye/neural-style]                                      101.1538     25.955      3.897      0.000      50.283     152.024
# C(repo_full_name)[T.antonmedv/llama]                                                363.7269     84.743      4.292      0.000     197.633     529.821
# C(repo_full_name)[T.approximatelabs/sketch]                                         672.4430    185.276      3.629      0.000     309.308    1035.578
# C(repo_full_name)[T.argosopentech/argos-train]                                     -138.4267     43.411     -3.189      0.001    -223.510     -53.343
# C(repo_full_name)[T.avisingh599/NeuralModels]                                     -1.543e-13     25.126  -6.14e-15      1.000     -49.245      49.245
# C(repo_full_name)[T.ayaka14732/tpu-starter]                                          52.0783     33.854      1.538      0.124     -14.274     118.430
# C(repo_full_name)[T.bayramn/QuoteReply-ChatGPT]                                    -214.0071     62.406     -3.429      0.001    -336.320     -91.694
# C(repo_full_name)[T.brunoamaral/gregory]                                           -210.6227     64.454     -3.268      0.001    -336.950     -84.295
# C(repo_full_name)[T.cair/tmu]                                                      -109.5589     53.639     -2.043      0.041    -214.689      -4.429
# C(repo_full_name)[T.carolynz/poetry-camera-rpi]                                    -143.2381     48.850     -2.932      0.003    -238.982     -47.494
# C(repo_full_name)[T.carpedm20/poet-neural]                                          -74.7030     32.601     -2.291      0.022    -138.600     -10.806
# C(repo_full_name)[T.comet-ml/comet-llm]                                             163.9009     46.217      3.546      0.000      73.316     254.485
# C(repo_full_name)[T.cysmith/neural-style-tf]                                         82.2044     20.025      4.105      0.000      42.955     121.453
# C(repo_full_name)[T.datumbox/Game-2048-AI-Solver]                                   -80.5643     33.709     -2.390      0.017    -146.633     -14.496
# C(repo_full_name)[T.davidrmiller/neural2d]                                          -75.0110     33.782     -2.220      0.026    -141.222      -8.800
# C(repo_full_name)[T.deepmind/neural_networks_chomsky_hierarchy]                      57.9102     27.232      2.127      0.033       4.536     111.284
# C(repo_full_name)[T.devongovett/SNNeuralNet]                                        -87.7492     31.040     -2.827      0.005    -148.587     -26.912
# C(repo_full_name)[T.devxpy/anti-chatgpt]                                           -117.3236     34.248     -3.426      0.001    -184.449     -50.198
# C(repo_full_name)[T.dimkr/tootik]                                                  -165.8174     60.034     -2.762      0.006    -283.483     -48.152
# C(repo_full_name)[T.dipjyotimetia/jarvis]                                          -221.3299     64.082     -3.454      0.001    -346.929     -95.731
# C(repo_full_name)[T.dod-advana/gamechanger]                                        -159.4267     44.555     -3.578      0.000    -246.752     -72.101
# C(repo_full_name)[T.dora-rs/dora]                                                   508.8239    103.590      4.912      0.000     305.791     711.857
# C(repo_full_name)[T.formkiq/formkiq-core]                                          -128.9573     42.308     -3.048      0.002    -211.879     -46.036
# C(repo_full_name)[T.fukun07/neural-image-captioning]                                 34.0309     27.777      1.225      0.221     -20.411      88.473
# C(repo_full_name)[T.fynnfluegge/rocketnotes]                                        -87.5607     44.437     -1.970      0.049    -174.655      -0.466
# C(repo_full_name)[T.geniusrise/geniusrise]                                         -185.1761     60.088     -3.082      0.002    -302.946     -67.406
# C(repo_full_name)[T.georgia-tech-db/eva]                                            797.9003    234.710      3.400      0.001     337.877    1257.924
# C(repo_full_name)[T.golivecosmos/llm-react-node-app-template]                      -145.8666     52.439     -2.782      0.005    -248.644     -43.089
# C(repo_full_name)[T.google/neural-light-transport]                                   -0.7030     31.286     -0.022      0.982     -62.022      60.616
# C(repo_full_name)[T.google/neural-logic-machines]                                    56.1847     26.100      2.153      0.031       5.030     107.339
# C(repo_full_name)[T.graphsignal/graphsignal-python]                                -138.7920     51.818     -2.678      0.007    -240.353     -37.231
# C(repo_full_name)[T.hades217/awesome-ai]                                            -56.7774     42.497     -1.336      0.182    -140.070      26.515
# C(repo_full_name)[T.ibigio/shell-ai]                                                -99.2649     31.223     -3.179      0.001    -160.461     -38.069
# C(repo_full_name)[T.iceburgcrm/iceburgcrm]                                          -84.0073     59.341     -1.416      0.157    -200.313      32.298
# C(repo_full_name)[T.intel/AiCSD]                                                   -183.3808     49.798     -3.682      0.000    -280.983     -85.778
# C(repo_full_name)[T.ivanbelenky/jsonllm]                                           -221.8684     64.783     -3.425      0.001    -348.840     -94.897
# C(repo_full_name)[T.jcjohnson/neural-style]                                         266.1081     28.754      9.255      0.000     209.751     322.465
# C(repo_full_name)[T.jfadev/jfa-whatsapp-chatbot]                                   -113.1415     63.610     -1.779      0.075    -237.815      11.532
# C(repo_full_name)[T.jhlau/topically-driven-language-model]                           -5.7811     23.624     -0.245      0.807     -52.083      40.521
# C(repo_full_name)[T.jirka-h/haveged]                                               -158.3917     60.965     -2.598      0.009    -277.880     -38.903
# C(repo_full_name)[T.jlmd/SimpleNeuralNetwork]                                       -56.5626     28.288     -2.000      0.046    -112.006      -1.119
# C(repo_full_name)[T.johan-akerman/SpotifyTranscripts]                               -94.4267     39.892     -2.367      0.018    -172.614     -16.239
# C(repo_full_name)[T.joone/loz]                                                      -37.4686     48.541     -0.772      0.440    -132.607      57.669
# C(repo_full_name)[T.jorgenkg/python-neural-network]                                 -76.5643     33.666     -2.274      0.023    -142.548     -10.581
# C(repo_full_name)[T.judahpaul16/gpt-home]                                           -35.8943     37.567     -0.955      0.339    -109.525      37.736
# C(repo_full_name)[T.kaievns/halmak]                                                -115.0840     58.830     -1.956      0.050    -230.389       0.221
# C(repo_full_name)[T.karlstroetmann/Artificial-Intelligence]                         -52.7867     27.456     -1.923      0.055    -106.599       1.026
# C(repo_full_name)[T.kehitysto/coaching-chatbot]                                     -51.3845     26.321     -1.952      0.051    -102.973       0.204
# C(repo_full_name)[T.kranzky/megahal]                                               -168.2293     44.862     -3.750      0.000    -256.157     -80.302
# C(repo_full_name)[T.lyndond/Analyzing_Neural_Time_Series]                           -65.6672     33.859     -1.939      0.052    -132.029       0.694
# C(repo_full_name)[T.makeyourownneuralnetwork/makeyourownneuralnetwork]              249.0076     27.545      9.040      0.000     195.020     302.995
# C(repo_full_name)[T.mbartoli/neural-animation]                                      -49.7164     28.241     -1.760      0.078    -105.067       5.634
# C(repo_full_name)[T.mgallo/openai.ex]                                                21.6503     36.746      0.589      0.556     -50.371      93.672
# C(repo_full_name)[T.miloharper/simple-neural-network]                                -5.4994     22.734     -0.242      0.809     -50.058      39.059
# C(repo_full_name)[T.miloharper/visualise-neural-network]                             15.1317     26.689      0.567      0.571     -37.177      67.440
# C(repo_full_name)[T.moein-shariatnia/OpenAI-CLIP]                                   127.9929     43.760      2.925      0.003      42.225     213.761
# C(repo_full_name)[T.narinluangrath/chatgpt-tui]                                    -187.3282     54.598     -3.431      0.001    -294.338     -80.318
# C(repo_full_name)[T.ncbi/GeneGPT]                                                   -32.5455     34.045     -0.956      0.339     -99.273      34.182
# C(repo_full_name)[T.nelhage/llama]                                                  -97.9653     43.312     -2.262      0.024    -182.855     -13.075
# C(repo_full_name)[T.neural-reckoning/neural-reckoning-website]                      -76.2566     33.724     -2.261      0.024    -142.354     -10.159
# C(repo_full_name)[T.nhaouari/obsidian-textgenerator-plugin]                         133.3574     53.637      2.486      0.013      28.231     238.484
# C(repo_full_name)[T.norvig/paip-lisp]                                               301.5585     52.535      5.740      0.000     198.591     404.526
# C(repo_full_name)[T.openai/grok]                                                   2200.9778    612.643      3.593      0.000    1000.220    3401.735
# C(repo_full_name)[T.openai/openai-gemm]                                             -23.8786     26.508     -0.901      0.368     -75.834      28.076
# C(repo_full_name)[T.ortegaalfredo/neuroengine]                                     -183.0391     58.923     -3.106      0.002    -298.526     -67.553
# C(repo_full_name)[T.pemami4911/neural-combinatorial-rl-pytorch]                      50.2967     31.976      1.573      0.116     -12.374     112.968
# C(repo_full_name)[T.phidatahq/phidata]                                             2849.8070   1149.305      2.480      0.013     597.211    5102.403
# C(repo_full_name)[T.piqoni/matcha]                                                  114.4964     36.562      3.132      0.002      42.837     186.156
# C(repo_full_name)[T.qxsch/ChatBot]                                                  -33.8919     23.908     -1.418      0.156     -80.750      12.966
# C(repo_full_name)[T.rasbt/MachineLearning-QandAI-book]                              -37.8535     45.617     -0.830      0.407    -127.261      51.554
# C(repo_full_name)[T.samueldobbie/markup]                                           -103.4600     46.952     -2.204      0.028    -195.485     -11.435
# C(repo_full_name)[T.semiosis/pen.el]                                                -79.3299     62.605     -1.267      0.205    -202.033      43.373
# C(repo_full_name)[T.shimoku-tech/shimoku-api-python]                               -161.9435     50.684     -3.195      0.001    -261.282     -62.605
# C(repo_full_name)[T.sourcegraph/awesome-code-ai]                                    267.6080     42.266      6.332      0.000     184.769     350.447
# C(repo_full_name)[T.spiceai/spiceai]                                                290.5163     79.120      3.672      0.000     135.444     445.589
# C(repo_full_name)[T.swirlai/swirl-search]                                           393.9580    140.072      2.813      0.005     119.422     668.493
# C(repo_full_name)[T.tensorflow/neural-structured-learning]                           19.1297     27.920      0.685      0.493     -35.592      73.852
# C(repo_full_name)[T.torappinfo/uweb]                                               -134.9313     56.651     -2.382      0.017    -245.964     -23.898
# C(repo_full_name)[T.trentsartain/Neural-Network]                                    -72.2492     30.984     -2.332      0.020    -132.977     -11.521
# C(repo_full_name)[T.trevorpogue/algebraic-nnhw]                                    -107.3917     40.926     -2.624      0.009    -187.606     -27.178
# C(repo_full_name)[T.vikasing/news-stopwords]                                       -226.9304     64.899     -3.497      0.000    -354.130     -99.731
# C(repo_full_name)[T.vladmandic/human]                                                55.9427     53.423      1.047      0.295     -48.764     160.649
# C(repo_full_name)[T.yanshengjia/artificial-intelligence]                              6.8715     26.077      0.264      0.792     -44.239      57.982
# C(repo_full_name)[T.yurijmikhalevich/rclip]                                         -59.3415     53.636     -1.106      0.269    -164.467      45.784
# C(repo_full_name)[T.yuvraj108c/4k-video-upscaler-colab]                            -166.4689     57.521     -2.894      0.004    -279.208     -53.730
# C(month)[T.2022-06]                                                                  -7.2342     56.480     -0.128      0.898    -117.933     103.465
# C(month)[T.2022-07]                                                                 -29.9895     65.812     -0.456      0.649    -158.979      99.000
# C(month)[T.2022-08]                                                                 -24.5586     57.746     -0.425      0.671    -137.739      88.621
# C(month)[T.2022-09]                                                                   8.9271     54.657      0.163      0.870     -98.199     116.053
# C(month)[T.2022-10]                                                                   5.5189     57.365      0.096      0.923    -106.915     117.953
# C(month)[T.2022-11]                                                                  25.0709     55.363      0.453      0.651     -83.439     133.581
# C(month)[T.2022-12]                                                                  41.8571     54.543      0.767      0.443     -65.045     148.760
# C(month)[T.2023-01]                                                                  84.5469     50.936      1.660      0.097     -15.286     184.380
# C(month)[T.2023-02]                                                                 110.4311     51.942      2.126      0.034       8.626     212.236
# C(month)[T.2023-03]                                                                 112.4569     53.858      2.088      0.037       6.897     218.016
# C(month)[T.2023-04]                                                                 117.8614     54.807      2.150      0.032      10.442     225.281
# C(month)[T.2023-05]                                                                 150.3503     53.971      2.786      0.005      44.569     256.131
# C(month)[T.2023-06]                                                                 162.1695     54.218      2.991      0.003      55.904     268.435
# C(month)[T.2023-07]                                                                 111.2860     75.267      1.479      0.139     -36.234     258.806
# C(month)[T.2023-08]                                                                 111.7221     66.782      1.673      0.094     -19.168     242.612
# C(month)[T.2023-09]                                                                  94.5959     66.508      1.422      0.155     -35.758     224.950
# C(month)[T.2023-10]                                                                 114.1160     63.211      1.805      0.071      -9.775     238.007
# C(month)[T.2023-11]                                                                 109.2033     63.714      1.714      0.087     -15.673     234.080
# C(month)[T.2023-12]                                                                 103.6400     65.127      1.591      0.112     -24.007     231.287
# C(month)[T.2024-01]                                                                 105.7523     58.676      1.802      0.071      -9.250     220.755
# C(month)[T.2024-02]                                                                 116.0840     59.181      1.962      0.050       0.091     232.077
# C(month)[T.2024-03]                                                                 140.9961     54.750      2.575      0.010      33.688     248.304
# C(month)[T.2024-04]                                                                 158.1174     59.134      2.674      0.007      42.216     274.019
# C(month)[T.2024-05]                                                                 220.6052     87.428      2.523      0.012      49.249     391.962
# C(month)[T.2024-06]                                                                 250.6655    102.588      2.443      0.015      49.597     451.734
# C(month)[T.2024-07]                                                                 288.4123    121.827      2.367      0.018      49.635     527.190
# C(month)[T.2024-08]                                                                 192.8691     61.530      3.135      0.002      72.273     313.465
# C(month)[T.2024-09]                                                                 217.9190     69.503      3.135      0.002      81.695     354.143
# C(month)[T.2024-10]                                                                 182.4026     55.942      3.261      0.001      72.758     292.048
# C(month)[T.2024-11]                                                                 197.6470     73.280      2.697      0.007      54.020     341.274
# did                                                                                 262.2789     34.083      7.695      0.000     195.477     329.081
# ==============================================================================
# Omnibus:                     2352.400   Durbin-Watson:                   0.454
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1727967.848
# Skew:                           6.396   Prob(JB):                         0.00
# Kurtosis:                     153.575   Cond. No.                         143.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
#
# ===== DiD with Fixed Effects: cumulative_forks =====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       cumulative_forks   R-squared:                       0.582
# Model:                            OLS   Adj. R-squared:                  0.550
# Method:                 Least Squares   F-statistic:                     89.98
# Date:                Tue, 08 Apr 2025   Prob (F-statistic):               0.00
# Time:                        11:21:17   Log-Likelihood:                -14508.
# No. Observations:                2524   AIC:                         2.938e+04
# Df Residuals:                    2342   BIC:                         3.044e+04
# Df Model:                         181
# Covariance Type:                  HC3
# ===================================================================================================================================================
#                                                                                       coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                                         -39.5172     12.514     -3.158      0.002     -64.044     -14.991
# C(repo_full_name)[T.AIPHPAndy/artificial-intelligence-php-mysql]                   36.0113     12.216      2.948      0.003      12.069      59.954
# C(repo_full_name)[T.AdrienGuille/GrowingNeuralGas]                                 40.4614     12.142      3.332      0.001      16.664      64.259
# C(repo_full_name)[T.Aggregate-Intellect/sherpa]                                     4.3077     15.913      0.271      0.787     -26.882      35.497
# C(repo_full_name)[T.Avaiga/taipy]                                                 243.0008     67.177      3.617      0.000     111.337     374.665
# C(repo_full_name)[T.BenderV/ada]                                                   -1.9231     16.043     -0.120      0.905     -33.366      29.520
# C(repo_full_name)[T.BobMcDear/attorch]                                              3.2165     14.322      0.225      0.822     -24.854      31.287
# C(repo_full_name)[T.BobbyAnguelov/NeuralNetwork]                                   35.1215     11.959      2.937      0.003      11.683      58.560
# C(repo_full_name)[T.CarperAI/OpenELM]                                              49.3704     13.790      3.580      0.000      22.343      76.398
# C(repo_full_name)[T.CeytiX/AI-Chatbot]                                             48.8496     12.301      3.971      0.000      24.741      72.958
# C(repo_full_name)[T.CodePilotai/codepilot]                                         36.5392     15.212      2.402      0.016       6.724      66.355
# C(repo_full_name)[T.Eroxl/Note-Rack]                                               18.7319     14.308      1.309      0.190      -9.311      46.775
# C(repo_full_name)[T.FalkorDB/FalkorDB]                                              6.2934     14.926      0.422      0.673     -22.961      35.548
# C(repo_full_name)[T.GT-RIPL/Awesome-LLM-Robotics]                                 132.9272     12.646     10.511      0.000     108.141     157.714
# C(repo_full_name)[T.GUR9000/KerasNeuralFingerprint]                                48.7950     12.043      4.052      0.000      25.190      72.400
# C(repo_full_name)[T.Giskard-AI/giskard]                                           179.5242     14.538     12.349      0.000     151.030     208.018
# C(repo_full_name)[T.GoogleCloudPlatform/cloud-deploy-chatbot]                      24.6199     12.116      2.032      0.042       0.874      48.366
# C(repo_full_name)[T.GoogleCloudPlatform/contact-center-ai-samples]                 42.9669     11.925      3.603      0.000      19.595      66.339
# C(repo_full_name)[T.GoogleCloudPlatform/dialogflow-chatbot]                        47.0476     12.388      3.798      0.000      22.768      71.327
# C(repo_full_name)[T.GoogleCloudPlatform/document-ai-samples]                      102.7422     12.131      8.470      0.000      78.967     126.518
# C(repo_full_name)[T.GoogleCloudPlatform/vertex-ai-alphafold-inference-pipeline]    48.9129     12.232      3.999      0.000      24.938      72.888
# C(repo_full_name)[T.GoogleCloudPlatform/vertex-ai-samples]                        530.1891     23.741     22.332      0.000     483.657     576.721
# C(repo_full_name)[T.HIPS/neural-fingerprint]                                       40.9660     11.959      3.426      0.001      17.527      64.405
# C(repo_full_name)[T.IndoNLP/indonlu]                                               67.0480     13.219      5.072      0.000      41.140      92.957
# C(repo_full_name)[T.JStumpp/awesome-chatbots]                                      36.2161     12.407      2.919      0.004      11.898      60.534
# C(repo_full_name)[T.Knight13/Exploring-Deep-Neural-Decision-Trees]                 19.7545     12.589      1.569      0.117      -4.919      44.428
# C(repo_full_name)[T.LucasBassetti/react-simple-chatbot]                            70.7192     13.000      5.440      0.000      45.239      96.199
# C(repo_full_name)[T.Merck/DeepNeuralNet-QSAR]                                      27.8457     12.764      2.182      0.029       2.829      52.862
# C(repo_full_name)[T.NeuralEnsemble/neuralensemble-docker]                          42.5776     12.471      3.414      0.001      18.136      67.019
# C(repo_full_name)[T.OutSorcerer/pocket-automl-android-tutorial]                     8.3373     13.348      0.625      0.532     -17.825      34.500
# C(repo_full_name)[T.Oxen-AI/oxen-release]                                          25.3885     14.246      1.782      0.075      -2.534      53.311
# C(repo_full_name)[T.PABannier/bark.cpp]                                            26.9857     13.641      1.978      0.048       0.250      53.722
# C(repo_full_name)[T.Puchaczov/Musoq]                                               -1.8671     16.563     -0.113      0.910     -34.330      30.596
# C(repo_full_name)[T.Robitx/gp.nvim]                                                25.0041     13.535      1.847      0.065      -1.525      51.533
# C(repo_full_name)[T.Sergio0694/NeuralNetwork.NET]                                  40.2863     12.711      3.169      0.002      15.373      65.200
# C(repo_full_name)[T.SharpAI/DeepCamera]                                            85.0671     12.030      7.071      0.000      61.489     108.645
# C(repo_full_name)[T.SuperDuperDB/superduperdb]                                    258.0810     54.834      4.707      0.000     150.609     365.553
# C(repo_full_name)[T.Tauffer-Consulting/domino]                                     35.3085     13.028      2.710      0.007       9.775      60.842
# C(repo_full_name)[T.UCDenver-ccp/ccp-nlp-pipelines]                                19.6776     12.584      1.564      0.118      -4.986      44.342
# C(repo_full_name)[T.agermanidis/SnapchatBot]                                       61.2195     12.323      4.968      0.000      37.066      85.373
# C(repo_full_name)[T.ahmadfaizalbh/Chatbot]                                        127.2728     13.655      9.321      0.000     100.510     154.036
# C(repo_full_name)[T.alafuzof/NeuralynxIO]                                          41.0182     12.560      3.266      0.001      16.401      65.636
# C(repo_full_name)[T.alexjc/neural-enhance]                                         92.7399     12.623      7.347      0.000      68.000     117.480
# C(repo_full_name)[T.alexrudall/ruby-openai]                                       104.7584     17.340      6.041      0.000      70.772     138.744
# C(repo_full_name)[T.alfredfrancis/ai-chatbot-framework]                            91.6204     12.293      7.453      0.000      67.526     115.715
# C(repo_full_name)[T.andersbll/neural_artistic_style]                               23.4155     12.152      1.927      0.054      -0.402      47.233
# C(repo_full_name)[T.android/neural-networks-samples]                               45.9412     12.536      3.665      0.000      21.371      70.511
# C(repo_full_name)[T.anishathalye/neural-style]                                     70.6052     12.387      5.700      0.000      46.327      94.883
# C(repo_full_name)[T.antonmedv/llama]                                               40.7384     12.048      3.381      0.001      17.125      64.352
# C(repo_full_name)[T.argosopentech/argos-train]                                     20.0186     14.513      1.379      0.168      -8.426      48.463
# C(repo_full_name)[T.ayaka14732/tpu-starter]                                        28.5123     13.804      2.066      0.039       1.457      55.567
# C(repo_full_name)[T.brunoamaral/gregory]                                           -2.6296     15.897     -0.165      0.869     -33.788      28.529
# C(repo_full_name)[T.cair/tmu]                                                       9.3887     16.179      0.580      0.562     -22.322      41.099
# C(repo_full_name)[T.carolynz/poetry-camera-rpi]                                     0.4473     14.836      0.030      0.976     -28.631      29.526
# C(repo_full_name)[T.carykh/neuralNetworkLanguageDetection]                         33.8465     12.608      2.684      0.007       9.135      58.558
# C(repo_full_name)[T.cgtuebingen/Neural-PIL]                                        48.2205     12.427      3.880      0.000      23.864      72.577
# C(repo_full_name)[T.chaiNNer-org/chaiNNer]                                        137.1934     13.409     10.232      0.000     110.913     163.474
# C(repo_full_name)[T.chenqinghe/baidu-ai-go-sdk]                                    37.3939     12.541      2.982      0.003      12.813      61.974
# C(repo_full_name)[T.chunyeow/openairinterface5g]                                   43.6336     12.583      3.468      0.001      18.971      68.296
# C(repo_full_name)[T.coder-hxl/x-crawl]                                             57.4473     12.929      4.443      0.000      32.106      82.789
# C(repo_full_name)[T.coderwilson/FFX_TAS_Python]                                    21.5454     13.756      1.566      0.117      -5.417      48.508
# C(repo_full_name)[T.comet-ml/comet-llm]                                            22.1538     15.029      1.474      0.140      -7.302      51.609
# C(repo_full_name)[T.cysmith/neural-style-tf]                                       60.4655     12.209      4.953      0.000      36.537      84.394
# C(repo_full_name)[T.danielpowney/my-chatbot]                                       32.5422     13.072      2.489      0.013       6.921      58.163
# C(repo_full_name)[T.daviddao/awful-ai]                                             22.7198     12.861      1.767      0.077      -2.487      47.926
# C(repo_full_name)[T.davidrmiller/neural2d]                                         43.4235     12.373      3.510      0.000      19.173      67.674
# C(repo_full_name)[T.dimkr/tootik]                                                  -6.8590     15.764     -0.435      0.663     -37.756      24.038
# C(repo_full_name)[T.dod-advana/gamechanger]                                        17.4032     14.525      1.198      0.231     -11.064      45.871
# C(repo_full_name)[T.dora-rs/dora]                                                  39.7692     13.153      3.024      0.002      13.990      65.549
# C(repo_full_name)[T.errata-ai/vale]                                                53.8011     13.163      4.087      0.000      28.002      79.600
# C(repo_full_name)[T.facebookresearch/CodeGen]                                      62.1934     12.532      4.963      0.000      37.631      86.755
# C(repo_full_name)[T.fetchai/uAgents]                                              136.2867     18.686      7.294      0.000      99.664     172.910
# C(repo_full_name)[T.formkiq/formkiq-core]                                          22.0396     14.119      1.561      0.119      -5.634      49.713
# C(repo_full_name)[T.fynnfluegge/rocketnotes]                                        4.0000     15.001      0.267      0.790     -25.402      33.402
# C(repo_full_name)[T.geniusrise/geniusrise]                                         -3.0000     16.226     -0.185      0.853     -34.801      28.801
# C(repo_full_name)[T.georgia-tech-db/eva]                                           84.3557     12.800      6.590      0.000      59.269     109.443
# C(repo_full_name)[T.golivecosmos/llm-react-node-app-template]                      12.9272     15.937      0.811      0.417     -18.309      44.163
# C(repo_full_name)[T.google/ios-chatbot]                                            33.9234     12.902      2.629      0.009       8.637      59.210
# C(repo_full_name)[T.google/neural-light-transport]                                 23.9084     12.604      1.897      0.058      -0.795      48.612
# C(repo_full_name)[T.google/neural-logic-machines]                                  45.4082     12.379      3.668      0.000      21.145      69.671
# C(repo_full_name)[T.google/neural-tangents]                                        88.3772     12.614      7.006      0.000      63.653     113.101
# C(repo_full_name)[T.googleapis/nodejs-ai-platform]                                 47.8084     12.469      3.834      0.000      23.369      72.248
# C(repo_full_name)[T.hades217/awesome-ai]                                           35.2200     13.577      2.594      0.009       8.610      61.830
# C(repo_full_name)[T.huggingface/llm-vscode]                                        29.5242     13.693      2.156      0.031       2.687      56.361
# C(repo_full_name)[T.hzexe/openair]                                                 49.1995     12.048      4.084      0.000      25.586      72.813
# C(repo_full_name)[T.ibigio/shell-ai]                                               22.4242     13.383      1.676      0.094      -3.805      48.654
# C(repo_full_name)[T.iceburgcrm/iceburgcrm]                                         17.9088     15.250      1.174      0.240     -11.981      47.798
# C(repo_full_name)[T.infostreams/neural-network]                                    30.0330     12.304      2.441      0.015       5.918      54.147
# C(repo_full_name)[T.intel/AiCSD]                                                   12.2315     15.251      0.802      0.423     -17.660      42.123
# C(repo_full_name)[T.intelligent-machine-learning/dlrover]                          98.6923     12.433      7.938      0.000      74.325     123.060
# C(repo_full_name)[T.jcjohnson/neural-style]                                        71.4139     11.993      5.955      0.000      47.908      94.919
# C(repo_full_name)[T.jfadev/jfa-whatsapp-chatbot]                                   17.5198     13.364      1.311      0.190      -8.673      43.713
# C(repo_full_name)[T.jina-ai/jina]                                                 491.0357     12.901     38.061      0.000     465.750     516.322
# C(repo_full_name)[T.jirka-h/haveged]                                                4.3637     16.561      0.263      0.792     -28.096      36.823
# C(repo_full_name)[T.johan-akerman/SpotifyTranscripts]                              24.3263     14.113      1.724      0.085      -3.334      51.987
# C(repo_full_name)[T.joone/loz]                                                      7.2867     15.914      0.458      0.647     -23.905      38.478
# C(repo_full_name)[T.jorgenkg/python-neural-network]                                49.2015     12.366      3.979      0.000      24.964      73.439
# C(repo_full_name)[T.judahpaul16/gpt-home]                                          12.0641     13.580      0.888      0.374     -14.552      38.681
# C(repo_full_name)[T.kaievns/halmak]                                                 0.5175     16.568      0.031      0.975     -31.956      32.991
# C(repo_full_name)[T.karlstroetmann/Artificial-Intelligence]                        29.2161     12.510      2.335      0.020       4.698      53.734
# C(repo_full_name)[T.karthink/gptel]                                                72.5426     12.553      5.779      0.000      47.939      97.146
# C(repo_full_name)[T.kranzky/megahal]                                               14.8969     14.544      1.024      0.306     -13.609      43.403
# C(repo_full_name)[T.logancyang/obsidian-copilot]                                   70.8469     12.784      5.542      0.000      45.790      95.904
# C(repo_full_name)[T.makeyourownneuralnetwork/makeyourownneuralnetwork]            171.3592     12.677     13.517      0.000     146.513     196.206
# C(repo_full_name)[T.mgallo/openai.ex]                                              60.9417     13.556      4.495      0.000      34.371      87.512
# C(repo_full_name)[T.moein-shariatnia/OpenAI-CLIP]                                  45.3637     14.402      3.150      0.002      17.137      73.590
# C(repo_full_name)[T.nadermx/backgroundremover]                                    209.4507     21.931      9.550      0.000     166.466     252.435
# C(repo_full_name)[T.narinluangrath/chatgpt-tui]                                     5.9272     16.160      0.367      0.714     -25.745      37.600
# C(repo_full_name)[T.ncbi/GeneGPT]                                                   8.5944     15.053      0.571      0.568     -20.910      38.098
# C(repo_full_name)[T.nelhage/llama]                                                 23.4517     14.033      1.671      0.095      -4.052      50.955
# C(repo_full_name)[T.nhaouari/obsidian-textgenerator-plugin]                        36.2121     12.749      2.840      0.005      11.225      61.199
# C(repo_full_name)[T.norvig/paip-lisp]                                              51.0198     12.299      4.148      0.000      26.915      75.125
# C(repo_full_name)[T.nxxcxx/Neural-Network]                                         26.1534     12.728      2.055      0.040       1.206      51.101
# C(repo_full_name)[T.openai/grok]                                                  267.8462     59.892      4.472      0.000     150.460     385.233
# C(repo_full_name)[T.openai/openai-gemm]                                            54.8349     12.294      4.460      0.000      30.739      78.931
# C(repo_full_name)[T.orhanerday/open-ai]                                           124.9269     20.837      5.996      0.000      84.088     165.766
# C(repo_full_name)[T.ortegaalfredo/neuroengine]                                      1.4203     16.907      0.084      0.933     -31.716      34.557
# C(repo_full_name)[T.oswaldoludwig/Seq2seq-Chatbot-for-Keras]                       23.7688     12.214      1.946      0.052      -0.170      47.708
# C(repo_full_name)[T.p0n1/epub_to_audiobook]                                        33.4623     12.447      2.688      0.007       9.066      57.859
# C(repo_full_name)[T.panchishin/neuralnet]                                          20.6776     12.584      1.643      0.100      -3.986      45.342
# C(repo_full_name)[T.paralleldrive/sudolang-llm-support]                            63.8392     13.350      4.782      0.000      37.673      90.005
# C(repo_full_name)[T.phidatahq/phidata]                                            417.3434    165.382      2.524      0.012      93.202     741.485
# C(repo_full_name)[T.pieroit/cheshire-cat]                                          79.1250     13.883      5.699      0.000      51.914     106.336
# C(repo_full_name)[T.piqoni/matcha]                                                 24.6340     14.490      1.700      0.089      -3.766      53.034
# C(repo_full_name)[T.plasma-umass/scalene]                                          60.8011     12.576      4.835      0.000      36.153      85.449
# C(repo_full_name)[T.promptfoo/promptfoo]                                          114.5944     18.849      6.080      0.000      77.651     151.538
# C(repo_full_name)[T.rasbt/LLMs-from-scratch]                                      697.1126    235.997      2.954      0.003     234.566    1159.659
# C(repo_full_name)[T.rasbt/MachineLearning-QandAI-book]                             33.7550     13.345      2.529      0.011       7.599      59.911
# C(repo_full_name)[T.rjmacarthy/twinny]                                             61.3704     12.513      4.905      0.000      36.846      85.895
# C(repo_full_name)[T.rksm/org-ai]                                                   44.2494     13.635      3.245      0.001      17.526      70.973
# C(repo_full_name)[T.run-llama/llama-lab]                                          107.6195     12.086      8.904      0.000      83.931     131.308
# C(repo_full_name)[T.salesforce/CodeGen]                                            93.7121     16.401      5.714      0.000      61.566     125.858
# C(repo_full_name)[T.samueldobbie/markup]                                           23.9122     14.051      1.702      0.089      -3.627      51.452
# C(repo_full_name)[T.sandrohanea/whisper.net]                                       57.6661     12.831      4.494      0.000      32.519      82.814
# C(repo_full_name)[T.semiosis/pen.el]                                                2.2308     16.310      0.137      0.891     -29.737      34.198
# C(repo_full_name)[T.shimoku-tech/shimoku-api-python]                                9.1580     15.995      0.573      0.567     -22.191      40.507
# C(repo_full_name)[T.skypilot-org/skypilot]                                        193.1934     22.050      8.762      0.000     149.976     236.411
# C(repo_full_name)[T.socketteer/loom]                                               42.6634     13.151      3.244      0.001      16.888      68.439
# C(repo_full_name)[T.sourcegraph/awesome-code-ai]                                   24.9857     13.671      1.828      0.068      -1.809      51.781
# C(repo_full_name)[T.spiceai/spiceai]                                               19.6154     14.069      1.394      0.163      -7.960      47.191
# C(repo_full_name)[T.swirlai/swirl-search]                                          67.4032     14.797      4.555      0.000      38.401      96.405
# C(repo_full_name)[T.titu1994/Neural-Style-Transfer]                                78.1084     12.288      6.357      0.000      54.025     102.192
# C(repo_full_name)[T.trevorpogue/algebraic-nnhw]                                     2.5175     15.665      0.161      0.872     -28.185      33.220
# C(repo_full_name)[T.vikasing/news-stopwords]                                       -6.1681     16.065     -0.384      0.701     -37.656      25.319
# C(repo_full_name)[T.vladmandic/human]                                              45.3373     14.374      3.154      0.002      17.165      73.509
# C(repo_full_name)[T.wladradchenko/wunjo.wladradchenko.ru]                          44.6931     12.169      3.673      0.000      20.842      68.544
# C(repo_full_name)[T.yanshengjia/artificial-intelligence]                           66.4084     12.104      5.486      0.000      42.685      90.132
# ...
# C(repo_full_name)[T.hades217/awesome-ai]                                           13.8282      2.798      4.942      0.000       8.345      19.312
# C(repo_full_name)[T.hellohaptik/chatbot_ner]                                       26.8126      1.926     13.924      0.000      23.039      30.587
# C(repo_full_name)[T.huggingface/llm-vscode]                                         3.8355      2.684      1.429      0.153      -1.425       9.096
# C(repo_full_name)[T.ibigio/shell-ai]                                                8.7471      2.478      3.530      0.000       3.890      13.604
# C(repo_full_name)[T.ibrahim4529/flask-chatbot]                                      9.3285      2.379      3.921      0.000       4.666      13.991
# C(repo_full_name)[T.iceburgcrm/iceburgcrm]                                          7.7586      2.904      2.672      0.008       2.068      13.450
# C(repo_full_name)[T.intel/AiCSD]                                                   18.2856      2.200      8.312      0.000      13.974      22.597
# C(repo_full_name)[T.intelligent-machine-learning/dlrover]                         109.9231      6.255     17.575      0.000      97.664     122.182
# C(repo_full_name)[T.intitni/CopilotForXcode]                                       17.9364      2.318      7.736      0.000      13.392      22.480
# C(repo_full_name)[T.ivanbelenky/jsonllm]                                           -7.6923      3.485     -2.207      0.027     -14.522      -0.862
# C(repo_full_name)[T.jfadev/jfa-whatsapp-chatbot]                                   11.9843      2.728      4.393      0.000       6.638      17.331
# C(repo_full_name)[T.jirka-h/haveged]                                               -4.0451      3.619     -1.118      0.264     -11.139       3.048
# C(repo_full_name)[T.johan-akerman/SpotifyTranscripts]                               3.1717      3.287      0.965      0.335      -3.271       9.615
# C(repo_full_name)[T.johnscape/NeuralNetwork]                                        2.0159      2.071      0.974      0.330      -2.043       6.074
# C(repo_full_name)[T.joone/loz]                                                     -0.1221      3.089     -0.040      0.968      -6.176       5.932
# C(repo_full_name)[T.judahpaul16/gpt-home]                                          -4.9867      2.965     -1.682      0.093     -10.798       0.825
# C(repo_full_name)[T.jupyterlab/jupyter-ai]                                         42.1717      7.022      6.006      0.000      28.409      55.934
# C(repo_full_name)[T.kaievns/halmak]                                                -4.7374      3.427     -1.382      0.167     -11.454       1.980
# C(repo_full_name)[T.karlstroetmann/Artificial-Intelligence]                         9.3057      1.887      4.931      0.000       5.607      13.005
# C(repo_full_name)[T.karthink/gptel]                                                35.6449      3.249     10.969      0.000      29.276      42.014
# C(repo_full_name)[T.kranzky/megahal]                                                1.6297      3.505      0.465      0.642      -5.240       8.499
# C(repo_full_name)[T.logancyang/obsidian-copilot]                                   12.2087      2.077      5.878      0.000       8.138      16.279
# C(repo_full_name)[T.makeyourownneuralnetwork/makeyourownneuralnetwork]              0.3800      1.998      0.190      0.849      -3.537       4.297
# C(repo_full_name)[T.mgallo/openai.ex]                                              24.0948      2.488      9.683      0.000      19.218      28.972
# C(repo_full_name)[T.microsoft/AI-For-Beginners]                                    55.6876      3.084     18.059      0.000      49.644      61.731
# C(repo_full_name)[T.microsoft/unilm]                                               77.1359      5.675     13.592      0.000      66.013      88.259
# C(repo_full_name)[T.miroslavpejic85/mirotalksfu]                                   27.1087      2.536     10.689      0.000      22.138      32.079
# C(repo_full_name)[T.mnementh64/neuralnetwork]                                      17.4202      2.500      6.969      0.000      12.521      22.320
# C(repo_full_name)[T.moein-shariatnia/OpenAI-CLIP]                                  -4.5067      3.350     -1.345      0.179     -11.073       2.059
# C(repo_full_name)[T.mothsoft/stanford-nlp-war]                                     11.4396      2.300      4.974      0.000       6.932      15.947
# C(repo_full_name)[T.nadermx/backgroundremover]                                     12.4369      2.294      5.422      0.000       7.941      16.933
# C(repo_full_name)[T.narinluangrath/chatgpt-tui]                                    -3.4320      3.572     -0.961      0.337     -10.434       3.570
# C(repo_full_name)[T.ncbi/GeneGPT]                                                  -4.7374      3.168     -1.495      0.135     -10.947       1.473
# C(repo_full_name)[T.nelhage/llama]                                                  4.3030      3.436      1.252      0.210      -2.432      11.038
# C(repo_full_name)[T.neural-reckoning/neural-reckoning-website]                     10.7020      1.860      5.754      0.000       7.057      14.347
# C(repo_full_name)[T.norvig/paip-lisp]                                              19.7843      2.653      7.457      0.000      14.584      24.985
# C(repo_full_name)[T.openai/grok]                                                   -4.4615      2.777     -1.607      0.108      -9.904       0.981
# C(repo_full_name)[T.openai/openai-cookbook]                                        85.6255     20.392      4.199      0.000      45.657     125.594
# C(repo_full_name)[T.openais/openais]                                                0.7861      2.254      0.349      0.727      -3.631       5.203
# C(repo_full_name)[T.orhanerday/open-ai]                                            34.5972      2.344     14.762      0.000      30.004      39.191
# C(repo_full_name)[T.ortegaalfredo/neuroengine]                                     -3.0086      3.270     -0.920      0.358      -9.419       3.401
# C(repo_full_name)[T.p0n1/epub_to_audiobook]                                         7.9779      2.067      3.859      0.000       3.926      12.030
# C(repo_full_name)[T.paralleldrive/sudolang-llm-support]                             5.4801      3.060      1.791      0.073      -0.517      11.477
# C(repo_full_name)[T.paul-gauthier/aider]                                           85.6817     11.629      7.368      0.000      62.890     108.474
# C(repo_full_name)[T.phidatahq/phidata]                                             40.8375      7.004      5.830      0.000      27.109      54.566
# C(repo_full_name)[T.pieroit/cheshire-cat]                                          33.9003      4.916      6.895      0.000      24.264      43.536
# C(repo_full_name)[T.piqoni/matcha]                                                  8.4794      3.087      2.747      0.006       2.429      14.530
# C(repo_full_name)[T.plasma-umass/scalene]                                          39.9332      2.451     16.293      0.000      35.130      44.737
# C(repo_full_name)[T.promptfoo/promptfoo]                                           55.8779     11.190      4.993      0.000      33.945      77.811
# C(repo_full_name)[T.rasbt/LLMs-from-scratch]                                        9.1452      3.101      2.949      0.003       3.067      15.223
# C(repo_full_name)[T.rasbt/MachineLearning-QandAI-book]                             -1.3952      2.936     -0.475      0.635      -7.151       4.360
# C(repo_full_name)[T.rjmacarthy/twinny]                                              9.3740      2.163      4.334      0.000       5.135      13.613
# C(repo_full_name)[T.rksm/org-ai]                                                   15.0179      2.249      6.677      0.000      10.609      19.426
# C(repo_full_name)[T.run-llama/llama-lab]                                            0.1834      3.463      0.053      0.958      -6.603       6.970
# C(repo_full_name)[T.salesforce/CodeGen]                                            20.5249      2.985      6.876      0.000      14.674      26.376
# C(repo_full_name)[T.samueldobbie/markup]                                           16.3600      2.639      6.199      0.000      11.188      21.532
# C(repo_full_name)[T.sandrohanea/whisper.net]                                       16.6297      2.108      7.888      0.000      12.498      20.762
# C(repo_full_name)[T.semiosis/pen.el]                                                4.2308      2.874      1.472      0.141      -1.403       9.864
# C(repo_full_name)[T.shimoku-tech/shimoku-api-python]                               22.7218      2.099     10.826      0.000      18.608      26.835
# C(repo_full_name)[T.socketteer/loom]                                               11.9772      2.626      4.561      0.000       6.830      17.124
# C(repo_full_name)[T.sourcegraph/awesome-code-ai]                                   19.4509      1.889     10.298      0.000      15.749      23.153
# C(repo_full_name)[T.spiceai/spiceai]                                               47.0000      7.883      5.962      0.000      31.550      62.450
# C(repo_full_name)[T.steven2358/awesome-generative-ai]                              52.5528      6.045      8.693      0.000      40.704      64.401
# C(repo_full_name)[T.swirlai/swirl-search]                                          51.9409      6.649      7.812      0.000      38.910      64.972
# C(repo_full_name)[T.tensorflow/neural-structured-learning]                         23.4245      2.106     11.122      0.000      19.297      27.552
# C(repo_full_name)[T.tmc/langchaingo]                                              128.6449     16.376      7.856      0.000      96.549     160.741
# C(repo_full_name)[T.tontyoutoure/DOTA2-AI-Fun]                                      7.8243      2.018      3.876      0.000       3.868      11.780
# C(repo_full_name)[T.torappinfo/uweb]                                               14.4436      2.986      4.837      0.000       8.591      20.297
# C(repo_full_name)[T.trevorpogue/algebraic-nnhw]                                    -3.5836      3.226     -1.111      0.267      -9.906       2.739
# C(repo_full_name)[T.vladmandic/human]                                              14.2341      2.821      5.046      0.000       8.705      19.763
# C(repo_full_name)[T.wladradchenko/wunjo.wladradchenko.ru]                           2.5933      2.595      0.999      0.318      -2.493       7.679
# C(repo_full_name)[T.yuvraj108c/4k-video-upscaler-colab]                            -7.2414      3.320     -2.181      0.029     -13.749      -0.734
# C(repo_full_name)[T.zkonduit/ezkl]                                                 56.7109      4.117     13.774      0.000      48.641      64.780
# C(month)[T.2022-06]                                                                 0.0437      3.420      0.013      0.990      -6.660       6.748
# C(month)[T.2022-07]                                                                -6.4158      4.411     -1.455      0.146     -15.061       2.229
# C(month)[T.2022-08]                                                                -6.7094      3.813     -1.760      0.078     -14.182       0.763
# C(month)[T.2022-09]                                                                -8.1166      3.636     -2.232      0.026     -15.244      -0.989
# C(month)[T.2022-10]                                                                -5.6439      3.277     -1.722      0.085     -12.066       0.778
# C(month)[T.2022-11]                                                                -3.2357      3.087     -1.048      0.295      -9.286       2.814
# C(month)[T.2022-12]                                                                -2.4403      3.067     -0.796      0.426      -8.452       3.572
# C(month)[T.2023-01]                                                                -1.5614      2.931     -0.533      0.594      -7.306       4.183
# C(month)[T.2023-02]                                                                 0.5121      2.772      0.185      0.853      -4.920       5.944
# C(month)[T.2023-03]                                                                 2.4942      2.741      0.910      0.363      -2.878       7.867
# C(month)[T.2023-04]                                                                 3.9718      2.749      1.445      0.148      -1.415       9.359
# C(month)[T.2023-05]                                                                 5.8541      2.826      2.072      0.038       0.315      11.393
# C(month)[T.2023-06]                                                                 6.6636      2.986      2.231      0.026       0.811      12.517
# C(month)[T.2023-07]                                                                 8.1547      3.005      2.714      0.007       2.265      14.044
# C(month)[T.2023-08]                                                                 7.9519      2.825      2.814      0.005       2.414      13.490
# C(month)[T.2023-09]                                                                 9.2872      2.768      3.355      0.001       3.861      14.713
# C(month)[T.2023-10]                                                                10.9463      2.723      4.020      0.000       5.609      16.283
# C(month)[T.2023-11]                                                                12.3799      2.708      4.571      0.000       7.072      17.688
# C(month)[T.2023-12]                                                                13.5055      2.713      4.978      0.000       8.188      18.823
# C(month)[T.2024-01]                                                                14.7866      2.708      5.460      0.000       9.478      20.095
# C(month)[T.2024-02]                                                                15.9643      2.723      5.863      0.000      10.628      21.301
# C(month)[T.2024-03]                                                                17.4663      2.767      6.311      0.000      12.042      22.890
# C(month)[T.2024-04]                                                                18.4848      2.839      6.510      0.000      12.920      24.050
# C(month)[T.2024-05]                                                                20.5002      2.934      6.988      0.000      14.750      26.250
# C(month)[T.2024-06]                                                                22.1836      3.013      7.364      0.000      16.279      28.088
# C(month)[T.2024-07]                                                                23.1591      3.092      7.491      0.000      17.099      29.219
# C(month)[T.2024-08]                                                                24.6295      3.302      7.459      0.000      18.158      31.101
# C(month)[T.2024-09]                                                                24.3651      3.282      7.425      0.000      17.933      30.797
# C(month)[T.2024-10]                                                                24.4254      3.789      6.447      0.000      16.999      31.851
# C(month)[T.2024-11]                                                                19.6351      3.826      5.132      0.000      12.136      27.135
# did                                                                                11.4760      0.806     14.233      0.000       9.896      13.056
# ==============================================================================
# Omnibus:                     1325.256   Durbin-Watson:                   0.496
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            47151.512
# Skew:                           1.333   Prob(JB):                         0.00
# Kurtosis:                      21.778   Cond. No.                         208.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)

# %% [markdown]
# # placebo test

# %%
import pandas as pd
import statsmodels.formula.api as smf
import os
import numpy as np
from linearmodels import PanelOLS  # For more robust estimation

# Directory containing the aligned files
aligned_dir = "aligned_did_outputs"
metrics = ['stars', 'forks', 'commits', 'prs', 've_contributors']
metric_column_map = {
    "stars": "cumulative_stars",
    "forks": "cumulative_forks",
    "commits": "cumulative_commits",
    "prs": "cumulative_prs",
    "ve_contributors": "cumulative_ve_contributors"
}

results = {}
placebo_results = {}

for metric in metrics:
    file_path = os.path.join(aligned_dir, f"aligned_did_{metric}.csv")
    df = pd.read_csv(file_path, parse_dates=['month', 'hn_submission_date'])

    if df.empty:
        print(f"[!] Skipping empty file: {file_path}")
        continue

    # ========== DATA PREP ==========
    # Create proper time variables
    df['time_period'] = df['month'].astype('str')  # For fixed effects
    df['month_diff'] = df['relative_month']  # Already appears to be months from treatment

    # Treatment indicators
    df['treatment'] = (df['repo_type'] == 'treatment').astype(int)
    df['post'] = df['post_treatment'].astype(int)
    df['did'] = df['treatment'] * df['post']
    outcome = metric_column_map[metric]

    # ========== IMPROVED DiD ANALYSIS ==========
    print(f"\n===== Enhanced DiD Analysis: {outcome} =====")

    # Option 1: Two-way fixed effects (more robust)
    try:
        df_panel = df.set_index(['repo_full_name', 'month'])
        model_twfe = PanelOLS.from_formula(
            f"{outcome} ~ treatment + post + did + EntityEffects + TimeEffects",
            data=df_panel
        ).fit(cov_type='clustered', cluster_entity=True)

        print("\nTwo-way FE model results:")
        print(model_twfe.summary)
    except Exception as e:
        print(f"PanelOLS failed: {str(e)}")

    # Option 2: OLS with repo clusters
    model_ols = smf.ols(
        formula=f"{outcome} ~ treatment + post + did + C(pair_id)",
        data=df
    ).fit(cov_type='cluster', cov_kwds={'groups': df['repo_full_name']})

    print("\nOLS with repo clustering:")
    print(model_ols.summary())

    # ========== DYNAMIC EFFECTS ==========
    print(f"\n----- Dynamic Effects for {outcome} -----")

    # Create event study indicators (avoiding the forbidden comparison)
    event_bins = [-6, -4, -2, 0, 2, 4, 6]
    df['event_window'] = pd.cut(df['month_diff'], bins=event_bins)

    # Run event study model
    event_model = smf.ols(
        f"{outcome} ~ C(event_window, Treatment(reference='[-6, -4)'))*treatment",
        data=df
    ).fit(cov_type='cluster', cov_kwds={'groups': df['repo_full_name']})

    print(event_model.summary().tables[1])

    # ========== PLACEBO TESTS ==========
    print(f"\n----- Placebo Tests for {outcome} -----")

    # Pre-treatment placebos (should show no effect)
    for months_before in [2, 4]:
        df[f'placebo_{months_before}'] = (df['month_diff'] == -months_before).astype(int)
        df[f'did_placebo_{months_before}'] = df['treatment'] * df[f'placebo_{months_before}']

        placebo_model = smf.ols(
            f"{outcome} ~ treatment + placebo_{months_before} + did_placebo_{months_before} + C(pair_id)",
            data=df
        ).fit(cov_type='cluster', cov_kwds={'groups': df['repo_full_name']})

        print(f"\nPlacebo {months_before} months before treatment:")
        print(placebo_model.summary().tables[1])
# Out:
# ===== Enhanced DiD Analysis: cumulative_stars =====
# PanelOLS failed:
# The model cannot be estimated. The included effects have fully absorbed
# one or more of the variables. This occurs when one or more of the dependent
# variable is perfectly explained using the effects included in the model.
#
# The following variables or variable combinations have been fully absorbed
# or have become perfectly collinear after effects are removed:
#
#           treatment
#
# Set drop_absorbed=True to automatically drop absorbed variables.
#
#
# OLS with repo clustering:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       cumulative_stars   R-squared:                       0.288
# Model:                            OLS   Adj. R-squared:                  0.258
# Method:                 Least Squares   F-statistic:                     15.43
# Date:                Wed, 09 Apr 2025   Prob (F-statistic):           3.56e-37
# Time:                        16:31:44   Log-Likelihood:                -13696.
# No. Observations:                1816   AIC:                         2.754e+04
# Df Residuals:                    1742   BIC:                         2.795e+04
# Df Model:                          73
# Covariance Type:              cluster
# ===================================================================================================================================================================
#                                                                                                       coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                                                         -84.2118     58.035     -1.451      0.147    -197.959      29.536
# C(pair_id)[T.Aggregate-Intellect/sherpa__vs__ZackAkil/rgb-neural-net]                               3.3077     76.567      0.043      0.966    -146.761     153.377
# C(pair_id)[T.BaihaiAI/IDP__vs__fukun07/neural-image-captioning]                                    10.9615     70.638      0.155      0.877    -127.486     149.409
# C(pair_id)[T.BenderV/ada__vs__CeytiX/AI-Chatbot]                                                    2.6154     74.330      0.035      0.972    -143.070     148.300
# C(pair_id)[T.BobMcDear/attorch__vs__AlfTang/Neural-Nework]                                        104.6538     59.592      1.756      0.079     -12.144     221.452
# C(pair_id)[T.CodePilotai/codepilot__vs__deepmind/neural_networks_chomsky_hierarchy]               117.1538     79.318      1.477      0.140     -38.306     272.613
# C(pair_id)[T.Eroxl/Note-Rack__vs__MichelDeudon/neural-combinatorial-optimization-rl-tensorflow]     7.1538     81.906      0.087      0.930    -153.379     167.687
# C(pair_id)[T.IndoNLP/indonlu__vs__cysmith/neural-style-tf]                                         94.5769     77.652      1.218      0.223     -57.619     246.772
# C(pair_id)[T.NeuralCoder3/transpilation__vs__jorgenkg/python-neural-network]                       -0.0385     79.135     -0.000      1.000    -155.141     155.064
# C(pair_id)[T.Oxen-AI/oxen-release__vs__5agado/recurrent-neural-networks-intro]                    149.0385     78.280      1.904      0.057      -4.388     302.465
# C(pair_id)[T.PABannier/bark.cpp__vs__alfredfrancis/ai-chatbot-framework]                          390.1154     57.011      6.843      0.000     278.376     501.855
# C(pair_id)[T.Puchaczov/Musoq__vs__karlstroetmann/Artificial-Intelligence]                           9.6154     78.270      0.123      0.902    -143.792     163.022
# C(pair_id)[T.ReadableLabs/readable-vscode__vs__avisingh599/NeuralModels]                           -7.1923     78.853     -0.091      0.927    -161.741     147.356
# C(pair_id)[T.Sets88/sets88_telegram_bot__vs__jlmd/SimpleNeuralNetwork]                              2.6538     75.614      0.035      0.972    -145.546     150.854
# C(pair_id)[T.Tauffer-Consulting/domino__vs__StackOverflowMATLABchat/NeuralNetPlayground]           12.6923     70.656      0.180      0.857    -125.790     151.175
# C(pair_id)[T.antonmedv/llama__vs__google/neural-logic-machines]                                   238.5000    117.299      2.033      0.042       8.598     468.402
# C(pair_id)[T.approximatelabs/sketch__vs__miloharper/visualise-neural-network]                     393.9231    236.976      1.662      0.096     -70.541     858.387
# C(pair_id)[T.argosopentech/argos-train__vs__openai/openai-gemm]                                    30.3846     78.110      0.389      0.697    -122.709     183.478
# C(pair_id)[T.ayaka14732/tpu-starter__vs__makeyourownneuralnetwork/makeyourownneuralnetwork]       227.2308     82.742      2.746      0.006      65.060     389.402
# C(pair_id)[T.bayramn/QuoteReply-ChatGPT__vs__SysCoder/tic-tac-toe-ai-engine]                       -7.4615     79.480     -0.094      0.925    -163.239     148.316
# C(pair_id)[T.brunoamaral/gregory__vs__davidrmiller/neural2d]                                        9.2308     78.631      0.117      0.907    -144.884     163.345
# C(pair_id)[T.cair/tmu__vs__tensorflow/neural-structured-learning]                                  75.9231     76.842      0.988      0.323     -74.684     226.530
# C(pair_id)[T.carolynz/poetry-camera-rpi__vs__devongovett/SNNeuralNet]                              34.8846     60.561      0.576      0.565     -83.813     153.582
# C(pair_id)[T.comet-ml/comet-llm__vs__makeyourownneuralnetwork/makeyourownneuralnetwork]           363.2308     71.769      5.061      0.000     222.567     503.895
# C(pair_id)[T.devxpy/anti-chatgpt__vs__GoogleCloudPlatform/healthcare-nlp-visualizer-demo]          27.5385     65.338      0.421      0.673    -100.522     155.598
# C(pair_id)[T.dimkr/tootik__vs__JStumpp/awesome-chatbots]                                           65.0769     81.077      0.803      0.422     -93.831     223.984
# C(pair_id)[T.dipjyotimetia/jarvis__vs__devongovett/SNNeuralNet]                                    -7.5769     78.974     -0.096      0.924    -162.363     147.209
# C(pair_id)[T.dod-advana/gamechanger__vs__qxsch/ChatBot]                                             5.3462     76.040      0.070      0.944    -143.690     154.382
# C(pair_id)[T.dora-rs/dora__vs__makeyourownneuralnetwork/makeyourownneuralnetwork]                 535.6923     95.357      5.618      0.000     348.796     722.589
# C(pair_id)[T.formkiq/formkiq-core__vs__miloharper/simple-neural-network]                           30.0000     75.517      0.397      0.691    -118.011     178.011
# C(pair_id)[T.fynnfluegge/rocketnotes__vs__openai/openai-gemm]                                      84.8077     60.881      1.393      0.164     -34.517     204.133
# C(pair_id)[T.geniusrise/geniusrise__vs__neural-reckoning/neural-reckoning-website]                 14.5769     71.969      0.203      0.839    -126.479     155.633
# C(pair_id)[T.georgia-tech-db/eva__vs__cysmith/neural-style-tf]                                    518.3462    257.612      2.012      0.044      13.435    1023.257
# C(pair_id)[T.golivecosmos/llm-react-node-app-template__vs__yanshengjia/artificial-intelligence]    53.7308     84.369      0.637      0.524    -111.630     219.092
# C(pair_id)[T.graphsignal/graphsignal-python__vs__RTBHOUSE/neural-network-native-ops]                0.1923     74.998      0.003      0.998    -146.800     147.185
# C(pair_id)[T.hades217/awesome-ai__vs__Sergio0694/NeuralNetwork.NET]                                65.8462     71.012      0.927      0.354     -73.335     205.027
# C(pair_id)[T.ibigio/shell-ai__vs__AIIX/Mycroft-AI-Gnome-Shell-Extension]                           29.4231     62.365      0.472      0.637     -92.810     151.656
# C(pair_id)[T.iceburgcrm/iceburgcrm__vs__pemami4911/neural-combinatorial-rl-pytorch]               135.1923     78.290      1.727      0.084     -18.254     288.639
# C(pair_id)[T.intel/AiCSD__vs__kehitysto/coaching-chatbot]                                          -3.9615     77.692     -0.051      0.959    -156.235     148.312
# C(pair_id)[T.ivanbelenky/jsonllm__vs__trentsartain/Neural-Network]                                 -0.1538     83.247     -0.002      0.999    -163.314     163.007
# C(pair_id)[T.jfadev/jfa-whatsapp-chatbot__vs__ahmetaa/turkish-nlp-examples]                       -29.6533     91.004     -0.326      0.745    -208.018     148.711
# C(pair_id)[T.jirka-h/haveged__vs__yanshengjia/artificial-intelligence]                             59.8846     85.869      0.697      0.486    -108.415     228.184
# C(pair_id)[T.johan-akerman/SpotifyTranscripts__vs__agermanidis/SnapchatBot]                        73.2308     77.513      0.945      0.345     -78.692     225.154
# C(pair_id)[T.joone/loz__vs__GoogleCloudPlatform/document-ai-samples]                              158.8846     74.274      2.139      0.032      13.311     304.458
# C(pair_id)[T.judahpaul16/gpt-home__vs__lyndond/Analyzing_Neural_Time_Series]                      107.6923     54.570      1.973      0.048       0.737     214.648
# C(pair_id)[T.kaievns/halmak__vs__google/neural-light-transport]                                    79.2308     73.277      1.081      0.280     -64.390     222.852
# C(pair_id)[T.kranzky/megahal__vs__abhiskk/fast-neural-style]                                        3.6923     80.994      0.046      0.964    -155.053     162.438
# C(pair_id)[T.mgallo/openai.ex__vs__LucasBassetti/react-simple-chatbot]                            189.7692     77.752      2.441      0.015      37.379     342.159
# C(pair_id)[T.moein-shariatnia/OpenAI-CLIP__vs__alfredfrancis/ai-chatbot-framework]                322.6923     73.464      4.393      0.000     178.705     466.679
# C(pair_id)[T.narinluangrath/chatgpt-tui__vs__karlstroetmann/Artificial-Intelligence]                4.8846     80.357      0.061      0.952    -152.612     162.381
# C(pair_id)[T.ncbi/GeneGPT__vs__BobbyAnguelov/NeuralNetwork]                                        88.9615     54.604      1.629      0.103     -18.060     195.983
# C(pair_id)[T.nelhage/llama__vs__Sergio0694/NeuralNetwork.NET]                                      64.2308     79.724      0.806      0.420     -92.025     220.486
# C(pair_id)[T.nhaouari/obsidian-textgenerator-plugin__vs__LucasBassetti/react-simple-chatbot]      136.3880     54.658      2.495      0.013      29.261     243.515
# C(pair_id)[T.norvig/paip-lisp__vs__alexjc/neural-enhance]                                         265.5467     57.209      4.642      0.000     153.419     377.674
# C(pair_id)[T.openai/grok__vs__openai/openai-gemm]                                                1229.0769    803.968      1.529      0.126    -346.672    2804.826
# C(pair_id)[T.ortegaalfredo/neuroengine__vs__ahmetaa/turkish-nlp-examples]                           7.0769     74.293      0.095      0.924    -138.534     152.688
# C(pair_id)[T.phidatahq/phidata__vs__yanshengjia/artificial-intelligence]                         1558.5769   1024.534      1.521      0.128    -449.473    3566.627
# C(pair_id)[T.piqoni/matcha__vs__jcjohnson/neural-style]                                           292.3077     82.910      3.526      0.000     129.807     454.808
# C(pair_id)[T.rasbt/MachineLearning-QandAI-book__vs__Sergio0694/NeuralNetwork.NET]                 141.7308     61.031      2.322      0.020      22.112     261.350
# C(pair_id)[T.samueldobbie/markup__vs__GoogleCloudPlatform/document-ai-samples]                     62.2692     84.924      0.733      0.463    -104.179     228.717
# C(pair_id)[T.semiosis/pen.el__vs__deepmind/neural_networks_chomsky_hierarchy]                     127.1154     75.228      1.690      0.091     -20.329     274.560
# C(pair_id)[T.shimoku-tech/shimoku-api-python__vs__mbartoli/neural-animation]                       15.3077     72.758      0.210      0.833    -127.295     157.910
# C(pair_id)[T.sourcegraph/awesome-code-ai__vs__LucasBassetti/react-simple-chatbot]                 375.5385     59.694      6.291      0.000     258.540     492.537
# C(pair_id)[T.spiceai/spiceai__vs__Sergio0694/NeuralNetwork.NET]                                   301.2308    105.179      2.864      0.004      95.084     507.378
# C(pair_id)[T.swirlai/swirl-search__vs__CognitiveBuild/Chatbot]                                    288.3077    152.964      1.885      0.059     -11.496     588.112
# C(pair_id)[T.torappinfo/uweb__vs__jhlau/topically-driven-language-model]                           -0.1538     76.960     -0.002      0.998    -150.993     150.685
# C(pair_id)[T.trevorpogue/algebraic-nnhw__vs__carpedm20/poet-neural]                                46.0769     57.829      0.797      0.426     -67.265     159.419
# C(pair_id)[T.vikasing/news-stopwords__vs__trentsartain/Neural-Network]                              0.8462     82.868      0.010      0.992    -161.572     163.264
# C(pair_id)[T.vladmandic/human__vs__AdrienGuille/GrowingNeuralGas]                                  36.6598     61.086      0.600      0.548     -83.067     156.387
# C(pair_id)[T.yurijmikhalevich/rclip__vs__anishathalye/neural-style]                                18.0467     87.538      0.206      0.837    -153.526     189.619
# C(pair_id)[T.yuvraj108c/4k-video-upscaler-colab__vs__JStumpp/awesome-chatbots]                     58.5769     81.387      0.720      0.472    -100.938     218.092
# treatment                                                                                           0.7348     39.364      0.019      0.985     -76.418      77.888
# post                                                                                               25.0894      5.323      4.714      0.000      14.658      35.521
# did                                                                                               299.6716    105.913      2.829      0.005      92.085     507.258
# ==============================================================================
# Omnibus:                     2904.859   Durbin-Watson:                   0.507
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          2202511.124
# Skew:                           9.942   Prob(JB):                         0.00
# Kurtosis:                     172.448   Cond. No.                         95.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
#
# ----- Dynamic Effects for cumulative_stars -----
# ---------------------------------------------------------------------------
# PatsyError                                Traceback (most recent call last)
# Cell In[5], line 73
#      70 df['event_window'] = pd.cut(df['month_diff'], bins=event_bins)
#      72 # Run event study model
# ---> 73 event_model = smf.ols(
#      74     f"{outcome} ~ C(event_window, Treatment(reference='[-6, -4)'))*treatment",
#      75     data=df
#      76 ).fit(cov_type='cluster', cov_kwds={'groups': df['repo_full_name']})
#      78 print(event_model.summary().tables[1])
#      80 # ========== PLACEBO TESTS ==========
#
# File c:\Users\prach\miniconda3\envs\naist-2025\Lib\site-packages\statsmodels\base\model.py:203, in Model.from_formula(cls, formula, data, subset, drop_cols, *args, **kwargs)
#     200 if missing == 'none':  # with patsy it's drop or raise. let's raise.
#     201     missing = 'raise'
# --> 203 tmp = handle_formula_data(data, None, formula, depth=eval_env,
#     204                           missing=missing)
#     205 ((endog, exog), missing_idx, design_info) = tmp
#     206 max_endog = cls._formula_max_endog
#
# File c:\Users\prach\miniconda3\envs\naist-2025\Lib\site-packages\statsmodels\formula\formulatools.py:63, in handle_formula_data(Y, X, formula, depth, missing)
#      61 else:
#      62     if data_util._is_using_pandas(Y, None):
# ---> 63         result = dmatrices(formula, Y, depth, return_type='dataframe',
#      64                            NA_action=na_action)
#      65     else:
#      66         result = dmatrices(formula, Y, depth, return_type='dataframe',
#      67                            NA_action=na_action)
#
# File c:\Users\prach\miniconda3\envs\naist-2025\Lib\site-packages\patsy\highlevel.py:319, in dmatrices(formula_like, data, eval_env, NA_action, return_type)
#     309 """Construct two design matrices given a formula_like and data.
#     310
#     311 This function is identical to :func:`dmatrix`, except that it requires
#    (...)    316 See :func:`dmatrix` for details.
#     317 """
#     318 eval_env = EvalEnvironment.capture(eval_env, reference=1)
# --> 319 (lhs, rhs) = _do_highlevel_design(
#     320     formula_like, data, eval_env, NA_action, return_type
#     321 )
#     322 if lhs.shape[1] == 0:
#     323     raise PatsyError("model is missing required outcome variables")
#
# File c:\Users\prach\miniconda3\envs\naist-2025\Lib\site-packages\patsy\highlevel.py:164, in _do_highlevel_design(formula_like, data, eval_env, NA_action, return_type)
#     161 def data_iter_maker():
#     162     return iter([data])
# --> 164 design_infos = _try_incr_builders(
#     165     formula_like, data_iter_maker, eval_env, NA_action
#     166 )
#     167 if design_infos is not None:
#     168     return build_design_matrices(
#     169         design_infos, data, NA_action=NA_action, return_type=return_type
#     170     )
#
# File c:\Users\prach\miniconda3\envs\naist-2025\Lib\site-packages\patsy\highlevel.py:56, in _try_incr_builders(formula_like, data_iter_maker, eval_env, NA_action)
#      54 if isinstance(formula_like, ModelDesc):
#      55     assert isinstance(eval_env, EvalEnvironment)
# ---> 56     return design_matrix_builders(
#      57         [formula_like.lhs_termlist, formula_like.rhs_termlist],
#      58         data_iter_maker,
#      59         eval_env,
#      60         NA_action,
#      61     )
#      62 else:
#      63     return None
#
# File c:\Users\prach\miniconda3\envs\naist-2025\Lib\site-packages\patsy\build.py:775, in design_matrix_builders(termlists, data_iter_maker, eval_env, NA_action)
#     773 design_infos = []
#     774 for termlist in termlists:
# --> 775     term_to_subterm_infos = _make_subterm_infos(
#     776         termlist, num_column_counts, cat_levels_contrasts
#     777     )
#     778     assert isinstance(term_to_subterm_infos, OrderedDict)
#     779     assert frozenset(term_to_subterm_infos) == frozenset(termlist)
#
# File c:\Users\prach\miniconda3\envs\naist-2025\Lib\site-packages\patsy\build.py:680, in _make_subterm_infos(terms, num_column_counts, cat_levels_contrasts)
#     677 levels, contrast = cat_levels_contrasts[factor]
#     678 # This is where the default coding is set to
#     679 # Treatment:
# --> 680 coded = code_contrast_matrix(
#     681     factor_coding[factor], levels, contrast, default=Treatment
#     682 )
#     683 contrast_matrices[factor] = coded
#     684 subterm_columns *= coded.matrix.shape[1]
#
# File c:\Users\prach\miniconda3\envs\naist-2025\Lib\site-packages\patsy\contrasts.py:642, in code_contrast_matrix(intercept, levels, contrast, default)
#     640     return contrast.code_with_intercept(levels)
#     641 else:
# --> 642     return contrast.code_without_intercept(levels)
#
# File c:\Users\prach\miniconda3\envs\naist-2025\Lib\site-packages\patsy\contrasts.py:184, in Treatment.code_without_intercept(self, levels)
#     182     reference = 0
#     183 else:
# --> 184     reference = _get_level(levels, self.reference)
#     185 eye = np.eye(len(levels) - 1)
#     186 contrasts = np.vstack(
#     187     (eye[:reference, :], np.zeros((1, len(levels) - 1)), eye[reference:, :])
#     188 )
#
# File c:\Users\prach\miniconda3\envs\naist-2025\Lib\site-packages\patsy\contrasts.py:127, in _get_level(levels, level_ref)
#     125         raise PatsyError("specified level %r is out of range" % (level_ref,))
#     126     return level_ref
# --> 127 raise PatsyError("specified level %r not found" % (level_ref,))
#
# PatsyError: specified level '[-6, -4)' not found
